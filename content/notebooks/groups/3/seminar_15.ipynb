# %% [markdown]
# # Словари 3
#
# _Dict comprehensions, сложные задачи_

# %% [markdown]
# #### Ответы на тест
# * В каком порядке хранятся данные в множествах (до 3.7) - **Порядка нет, священный рандом**
# * Соедините понятие и функцию -
#     * объединение - **Union**
#     * пересечение - **Intersection**
#     * вычитание - **-**
# * Как вызвать библиотеку для работы с файлами json? - **import json**
# * Общее количество медалей Бразилии -
# ```python
# from csv import DictReader
# olympics = DictReader(open('olympics.csv'))
# for country in olympics:
#     if country['Country'] == 'Brazil (BRA)':
#         print(country['Combined total'])
# ```
# * Выведите все страны, у которых медалей за зимние игры больше, чем за летние
# ```python
# from csv import DictReader
# olympics = DictReader(open('olympics.csv'))
# for country in olympics:
#     if int(country['# Winter']) > int(country['# Summer']):
#         print(country['Country'])
# ```
# * Выведите все страны, у которых больше 50 медалей в сумме
# ```python
# from csv import DictReader
# olympics = DictReader(open('olympics.csv'))
# for country in olympics:
#     if int(country['Combined total']) > 50 and country['Country'] != 'Totals':
#         print(country['Country'])
# ```

# %% [markdown]
# ## Dict comprehensions

# %% [markdown]
# ### Теория
#
# Сокращения словарей — один из способов сократить количество строк кода, когда нужно завести словарь динамически, основываясь на переборе элементов for-циклом.
#
# **Было**

# %%
keys_list = ["key1", "key2", "key3"]
my_dict = {}
for item in keys_list:
    my_dict[item] = 0

# %%
my_dict
# Out:
# {'key1': 0, 'key2': 0, 'key3': 0}

# %% [markdown]
# **Стало**

# %%
keys_list = ["key1", "key2", "key3"]
my_dict = {key: 0 for key in keys_list}

# %%
my_dict
# Out:
# {'key1': 0, 'key2': 0, 'key3': 0}

# %%
keys_list = "key1"
my_dict = {key: 0 for key in keys_list}

# %%
my_dict
# Out:
# {'k': 0, 'e': 0, 'y': 0, '1': 0}

# %% [markdown]
# ### Алгоритм
#
# Как написать такое сокращение:
#
# 1. определяемся с переменной, откуда будем брать ключи (список, строка, etc.)
# 2. определяемся с тем, как будет выглядеть значение
# 3. укладываем в формулу: `{ключ: значение for ключ in переменная_с_ключами}`

# %% [markdown]
# ### Практика

# %% [markdown]
# Следующие три цикла нужно свернуть в dict comprehension:

# %%
names = ["Аня", "Ваня", "Петя", "Соня"]
name_length = {}
for name in names:
    name_length[name] = len(name)

# %%
name_length
# Out:
# {'Аня': 3, 'Ваня': 4, 'Петя': 4, 'Соня': 4}

# %%
name_lens = {name: len(name) for name in names}
name_lens
# Out:
# {'Аня': 3, 'Ваня': 4, 'Петя': 4, 'Соня': 4}

# %%
name_length = {key: len(key) for key in names}
name_length
# Out:
# {'Аня': 3, 'Ваня': 4, 'Петя': 4, 'Соня': 4}

# %%
vowels = "аеёиоуэюя"
vowel_codes = {}
for vowel in vowels:
    vowel_codes[vowel] = ord(vowel)
vowel_codes
# Out:
# {'а': 1072,
#  'е': 1077,
#  'ё': 1105,
#  'и': 1080,
#  'о': 1086,
#  'у': 1091,
#  'э': 1101,
#  'ю': 1102,
#  'я': 1103}

# %%
vowels = "аеёиоуэюя"
vowel_codes = {vowel: ord(vowel) for vowel in vowels}

# %%
vowel_codes
# Out:
# {'а': 1072,
#  'е': 1077,
#  'ё': 1105,
#  'и': 1080,
#  'о': 1086,
#  'у': 1091,
#  'э': 1101,
#  'ю': 1102,
#  'я': 1103}

# %%
ord()

# %%
sentence = "Все счастливые семьи похожи друг на друга, каждая несчастливая семья несчастлива по-своему"
words = {}
for word in sentence.split():
    words[word] = 0
words
# Out:
# {'Все': 0,
#  'счастливые': 0,
#  'семьи': 0,
#  'похожи': 0,
#  'друг': 0,
#  'на': 0,
#  'друга,': 0,
#  'каждая': 0,
#  'несчастливая': 0,
#  'семья': 0,
#  'несчастлива': 0,
#  'по-своему': 0}

# %%
sentence = "Все счастливые семьи похожи друг на друга, каждая несчастливая семья несчастлива по-своему"

words ={word: 0 for word in sentence.split()}
words
# Out:
# {'Все': 0,
#  'счастливые': 0,
#  'семьи': 0,
#  'похожи': 0,
#  'друг': 0,
#  'на': 0,
#  'друга,': 0,
#  'каждая': 0,
#  'несчастливая': 0,
#  'семья': 0,
#  'несчастлива': 0,
#  'по-своему': 0}

# %% [markdown]
# Следующие три сокращения нужно развернуть в циклы:

# %%
greetings = ["hello", "hi", "hello", "today", "morning", "again", "hello"]
greetings_reversed = {greet: greet[::-1] for greet in greetings}
greetings_reversed
# Out:
# {'hello': 'olleh',
#  'hi': 'ih',
#  'today': 'yadot',
#  'morning': 'gninrom',
#  'again': 'niaga'}

# %%
greetings = ["hello", "hi", "hello", "today", "morning", "again", "hello"]
greetings_reversed = {}
for greet in greetings:
    greetings_reversed[greet] = greet[::-1]
greetings_reversed
# Out:
# {'hello': 'olleh',
#  'hi': 'ih',
#  'today': 'yadot',
#  'morning': 'gninrom',
#  'again': 'niaga'}

# %%
hashes = {number: hash(number)^2 for number in range(10)}

# %%
hashes
# Out:
# {0: 2, 1: 3, 2: 0, 3: 1, 4: 6, 5: 7, 6: 4, 7: 5, 8: 10, 9: 11}

# %%
nums = list(range(10))
hashes = {}
for num in nums:
    hashes[num] = hash(num)^2
hashes
# Out:
# {0: 2, 1: 3, 2: 0, 3: 1, 4: 6, 5: 7, 6: 4, 7: 5, 8: 10, 9: 11}

# %%
hash()
# Out:
# 17

# %%
hashes = {}
for i in range(10):
    hashes[i] = hash(i)**2

# %%
from random import choice
grades = {surname: choice(list(range(1,11))) for surname in ["Студент1", "Студент2", "Студент3"]}

# %%
grades
# Out:
# {'Студент1': 6, 'Студент2': 5, 'Студент3': 2}

# %%
from random import choice
grades = {}
for surname in ["Студент1", "Студент2", "Студент3"]:
    grades[surname] = choice(list(range(1,11)))

# %%
grades
# Out:
# {'Студент1': 1, 'Студент2': 2, 'Студент3': 3}

# %% [markdown]
# ## Соединяем словари и другие структуры: задачи

# %% [markdown]
# ### Задача полегче

# %% [markdown]
# Возьмите текст Франкенштейна по ссылке: https://gutenberg.org/files/84/84-0.txt
#
# Для каждого уникального слова в тексте составьте список слов-«соседей» — то есть слов слева и справа от заданного. Получившийся список отсортируйте в лексикографическом порядке и оставьте первые 5 слов.

# %%
with open("frankenstein.txt", "r", encoding="utf-8-sig") as src:
    frankenstein = src.read()
    
frank_words = frankenstein.lower().split()
neigh = {}
for i, word in enumerate(frank_words):
    existing_neighbours = neigh.get(word, [])
    if i-1 > 0:
        existing_neighbours.append(frank_words[i-1])
    if i+1 < len(frank_words):
        existing_neighbours.append(frank_words[i+1])
    neigh[word] = existing_neighbours

# your code here

# %%
for key in neigh:
    neigh[key] = sorted(neigh[key])[:5]

# %%
neigh
# Out:
# {'the': ['"right', '(as', '1.c.', '1.d.', '1.e.1.'],
#  'project': ['1.f.1.', 'a', 'a', 'a', 'a'],
#  'gutenberg': ['are', 'ebook', 'ebook', 'ebook', 'ebooks'],
#  'ebook': ['for', 'frankenstein', 'frankenstein', 'gutenberg', 'gutenberg'],
#  'of': ['"right', '20%', '20%', '27th', '_paradise'],
#  'frankenstein,': ['be', 'by', 'dear', 'heard!', 'i'],
#  'by': ['(or', '1.a.', '_ennui_,', 'a', 'a'],
#  'mary': ['author:', 'by', 'by', 'wollstonecraft', 'wollstonecraft'],
#  'wollstonecraft': ['(godwin)', '(godwin)', '(godwin)', 'mary', 'mary'],
#  '(godwin)': ['shelley',
#   'shelley',
#   'shelley',
#   'wollstonecraft',
#   'wollstonecraft'],
#  'shelley': ['(godwin)', '(godwin)', '(godwin)', 'contents', 'release'],
#  'this': ['*****', '*****', '1.f.3,', '17—”', 'a'],
#  'is': ['64-6221541.', 'a', 'a', 'a', 'a'],
#  'for': ['a', 'a', 'a', 'a', 'a'],
#  'use': ['all', 'already', 'and', 'and', 'for'],
#  'anyone': ['anywhere', 'anywhere', 'except', 'foundation,', 'if'],
#  'anywhere': ['anyone', 'anyone', 'in', 'in'],
#  'in': ['(inexperience', '2001,', 'a', 'a', 'a'],
#  'united': ['a', 'apparently', 'be', 'be', 'by'],
#  'states': ['50', 'and', 'and', 'and', 'copyright'],
#  'and': ['(c)', '1.e.7', '3', '4', '4'],
#  'most': ['a', 'a', 'a', 'a', 'a'],
#  'other': ['all', 'alterations,', 'among', 'and', 'and'],
#  'parts': ['deeper', 'formed', 'of', 'of', 'of'],
#  'world': ['a', 'a', 'a', 'affords', 'again'],
#  'at': ['809', 'a', 'a', 'a', 'a'],
#  'no': ['accident', 'account.', 'additional', 'advance,', 'affections,'],
#  'cost': ['and', 'and', 'no', 'no'],
#  'with': ["'as-is',", '1.e.1', 'a', 'a', 'a'],
#  'almost': ['a', 'adored', 'amounted', 'an', 'an'],
#  'restrictions': ['no', 'no', 'whatsoever.', 'whatsoever.'],
#  'whatsoever.': ['restrictions', 'restrictions', 'you', 'you'],
#  'you': ["'as-is',", '(www.gutenberg.org),', '*', '*', '*'],
#  'may': ['12th,', '18th,', 'afford', 'again', 'again'],
#  'copy': ['a', 'a', 'and', 'any', 'can'],
#  'it,': ['across', 'although', 'and', 'and', 'and'],
#  'give': ['an', 'an', 'an', 'an', 'and'],
#  'it': ['12th.', '23', '5', 'a', 'a'],
#  'away': ['all', 'and', 'and', 'borne', 'borne'],
#  'or': ['(so', '1.e.7', '1.e.8', '1.e.8', '1.e.9.'],
#  're-use': ['it', 'it', 'or', 'or'],
#  'under': ['a', 'a', 'daughter', 'desires', 'die'],
#  'terms': ['additional', 'additional', 'ardent', 'different', 'enthusiastic'],
#  'license': ['and', 'as', 'available', 'for', 'full'],
#  'included': ['a', 'license', 'license', 'they', 'with'],
#  'online': ['at', 'at', 'at', 'checks,', 'or'],
#  'www.gutenberg.org.': ['at', 'at', 'if', 'if'],
#  'if': ['-', '1.e.2.', '1.e.3.', '1.e.9.', 'a'],
#  'are': ['$5,000)', '(or', '_you_', 'a', 'a'],
#  'not': ['(does', 'a', 'a', 'a', 'a'],
#  'located': ['also', 'are', 'are', 'are', 'are'],
#  'states,': ['check', 'united', 'united', 'united', 'united'],
#  'will': ['accompany', 'afford', 'agreement', 'all', 'allow'],
#  'have': ['a', 'a', 'a', 'a', 'a'],
#  'to': ['$5,000)', '($1', 'a', 'a', 'a'],
#  'check': ['only', 'please', 'states,', 'the', 'the'],
#  'laws': ['alone', 'and', 'and', 'copyright', 'copyright'],
#  'country': ['a', 'a', 'and', 'and', 'and'],
#  'where': ['and', 'and', 'and', 'any', 'but'],
#  'before': ['acting', 'agatha.', 'agreement', 'always', 'and'],
#  'using': ['and', 'any', 'before', 'before', 'by'],
#  'ebook.': ['1.e.2.', 'this', 'this', 'title:'],
#  'title:': ['ebook.', 'frankenstein'],
#  'frankenstein': ['***', '***', 'call', 'desolation.', 'discovered'],
#  'or,': ['danger,', 'doing;', 'frankenstein', 'frankenstein;', 'if'],
#  'modern': ['a', 'against', 'chemistry,', 'chemists;', 'inquirers'],
#  'prometheus': ['author:', 'by', 'modern', 'modern'],
#  'author:': ['mary', 'prometheus'],
#  'release': ['date:', 'shelley'],
#  'date:': ['31,', 'release'],
#  '31,': ['1993', 'date:'],
#  '1993': ['31,', '[ebook'],
#  '[ebook': ['#84]', '1993'],
#  '#84]': ['[ebook', '[most'],
#  '[most': ['#84]', 'recently'],
#  'recently': ['[most', 'updated:'],
#  'updated:': ['november', 'recently'],
#  'november': ['13,', 'of', 'that', 'updated:'],
#  '13,': ['2020]', 'november'],
#  '2020]': ['13,', 'language:'],
#  'language:': ['2020]', 'english'],
#  'english': ['an', 'an', 'character', 'history.', 'history.'],
#  'character': ['contained', 'english', 'his', 'i', 'my'],
#  'set': ['a', 'a', 'are', 'as', 'as'],
#  'encoding:': ['set', 'utf-8'],
#  'utf-8': ['encoding:', 'produced'],
#  'produced': ['a', 'against', 'and', 'and', 'by:'],
#  'by:': ['judith', 'produced'],
#  'judith': ['boss,', 'by:'],
#  'boss,': ['christy', 'judith'],
#  'christy': ['boss,', 'phillips,'],
#  'phillips,': ['christy', 'lynn'],
#  'lynn': ['hanninen,', 'phillips,'],
#  'hanninen,': ['and', 'lynn'],
#  'david': ['and', 'meltzer.'],
#  'meltzer.': ['david', 'html'],
#  'html': ['meltzer.', 'version'],
#  'version': ['by', 'html', 'official', 'posted'],
#  'al': ['by', 'haines.'],
#  'haines.': ['al', 'further'],
#  'further': ['corrections', 'haines.', 'he', 'opportunities', 'the'],
#  'corrections': ['by', 'further'],
#  'menno': ['by', 'de'],
#  'de': ['and', 'free', 'lacey', 'lacey', 'lacey'],
#  'leeuw.': ['***', 'de'],
#  '***': ['*****', 'distance.', 'end', 'frankenstein', 'frankenstein'],
#  'start': ['***', 'at', 'of', 'people'],
#  'frankenstein;': ['***', 'my', 'or,', 'pitied'],
#  'contents': ['letter', 'shelley'],
#  'letter': ['1', '1', '1', '2', '2'],
#  '1': ['_to', 'chapter', 'chapter', 'chapter', 'i'],
#  '2': ['_to', 'chapter', 'chapter', 'chapter', 'letter'],
#  '3': ['_to', 'and', 'below.', 'chapter', 'chapter'],
#  '4': ['_to', 'and', 'and', 'chapter', 'chapter'],
#  'chapter': ['1', '1', '1', '10', '10'],
#  '5': ['chapter', 'chapter', 'chapter', 'it'],
#  '6': ['chapter', 'chapter', 'chapter', 'clerval'],
#  '7': ['chapter', 'chapter', 'chapter', 'on'],
#  '8': ['chapter', 'chapter', 'chapter', 'we'],
#  '9': ['chapter', 'chapter', 'chapter', 'nothing'],
#  '10': ['chapter', 'chapter', 'chapter', 'i'],
#  '11': ['chapter', 'chapter', 'chapter', '“it'],
#  '12': ['chapter', 'chapter', 'chapter', '“i'],
#  '13': ['chapter', 'chapter', 'chapter', '“i'],
#  '14': ['chapter', 'chapter', 'chapter', '“some'],
#  '15': ['chapter', 'chapter', 'chapter', '“such'],
#  '16': ['chapter', 'chapter', 'chapter', '“cursed,'],
#  '17': ['chapter', 'chapter', 'chapter', 'the'],
#  '18': ['chapter', 'chapter', 'chapter', 'day'],
#  '19': ['chapter', 'chapter', 'chapter', 'london'],
#  '20': ['chapter', 'chapter', 'chapter', 'i'],
#  '21': ['chapter', 'chapter', 'chapter', 'i'],
#  '22': ['chapter', 'chapter', 'chapter', 'the'],
#  '23': ['chapter', 'chapter', 'chapter', 'it'],
#  '24': ['chapter', 'chapter', 'letter', 'my'],
#  '_to': ['1', '2', '3', '4', 'be'],
#  'mrs.': ['_to', '_to', '_to', '_to', 'saville,'],
#  'saville,': ['england._', 'england._', 'england._', 'england._', 'mrs.'],
#  'england._': ['archangel,', 'august', 'july', 'saville,', 'saville,'],
#  'st.': ['andrew’s,', 'bernard’s', 'between', 'coupar,', 'england._'],
#  'petersburgh,': ['dec.', 'i', 'of', 'st.'],
#  'dec.': ['11th,', 'petersburgh,'],
#  '11th,': ['17—.', 'dec.'],
#  '17—.': ['11th,', '13th,', '19th,', '26th,', '5th,'],
#  'rejoice': ['to', 'will'],
#  'hear': ['about', 'all.”', 'and', 'but', 'draught?'],
#  'that': ['_you_', 'a', 'a', 'a', 'a'],
#  'disaster': ['has', 'is', 'no', '“your'],
#  'has': ['a', 'a', 'a', 'a', 'a'],
#  'accompanied': ['by', 'by', 'by', 'by', 'has'],
#  'commencement': ['its', 'of', 'of', 'of', 'of'],
#  'an': ['abortion,', 'about', 'about', 'abroad', 'absorbing'],
#  'enterprise': ['an', 'which'],
#  'which': ['a', 'a', 'a', 'accidents', 'admit'],
#  'regarded': ['all', 'almost', 'as', 'as', 'be'],
#  'such': ['"defects,"', '(for', 'a', 'a', 'a'],
#  'evil': ['an', 'an', 'an', 'and', 'any'],
#  'forebodings.': ['evil', 'i'],
#  'i': ['(although', '(although', '1', '10', '20'],
#  'arrived': ['and', 'at', 'at', 'at', 'at'],
#  'here': ['alps', 'also', 'also', 'and', 'and'],
#  'yesterday,': ['and', 'here'],
#  'my': ['(so', '17—.', '17—.', '24', 'abandon'],
#  'first': ['affords', 'approach', 'arrived,', 'at', 'at'],
#  'task': ['a', 'a', 'enjoined', 'first', 'in'],
#  'assure': ['can', 'i', 'i', 'my', 'themselves'],
#  'dear': ['again', 'ah,', 'and', 'and', 'and'],
#  'sister': ['a', 'and', 'and', 'dear', 'died;'],
#  'welfare': ['and', 'and', 'my', 'their'],
#  'increasing': ['and', 'confidence', 'of', 'the'],
#  'confidence': ['and', 'between', 'in', 'in', 'increasing'],
#  'success': ['_shall_', 'and', 'but', 'eventual', 'first'],
#  'undertaking.': ['honourable', 'i', 'i', 'it', 'my'],
#  'am': ['a', 'a', 'a', 'abandoned,', 'about'],
#  'already': ['accomplished.', 'adopted,', 'am', 'are', 'been'],
#  'far': ['a', 'a', 'above', 'advanced', 'advanced'],
#  'north': ['1500', '809', 'and', 'as', 'at'],
#  'london,': ['and', 'in', 'of', 'of', 'st.'],
#  'as': ['_good,', 'a', 'a', 'a', 'a'],
#  'walk': ['doth', 'farther', 'i', 'in', 'in'],
#  'streets': ['are', 'of', 'of', 'the', 'the'],
#  'feel': ['a', 'again', 'all', 'and', 'as'],
#  'a': ['1.f.3,', '5th.', '_campagne_', 'abhorred.', 'aboard'],
#  'cold': ['a', 'a', 'a', 'also,', 'amidst'],
#  'northern': ['breeze', 'cold', 'extremity', 'highlands', 'highlands'],
#  'breeze': ['a', 'a', 'and', 'blows', 'dissipated'],
#  'play': ['and', 'before.', 'breeze', 'fish', 'him'],
#  'upon': ['a', 'and', 'and,', 'animation', 'animation'],
#  'cheeks,': ['and', 'my', 'my', 'which'],
#  'braces': ['my', 'which'],
#  'nerves': ['and', 'my', 'my', 'were'],
#  'fills': ['and', 'delayed', 'grief', 'he', 'me'],
#  'me': ['(wretched', 'a', 'a', 'a', 'a'],
#  'delight.': ['and', 'and', 'and', 'and', 'as'],
#  'do': ['1.e.4.', '1.e.5.', '1.e.7.', 'again', 'again'],
#  'understand': ['and', 'even', 'him,', 'i', 'not'],
#  'feeling?': ['this', 'this'],
#  'breeze,': ['this', 'which'],
#  'travelled': ['and', 'at', 'from', 'has', 'i'],
#  'from': ['4', 'a', 'a', 'a', 'a'],
#  'regions': ['i', 'mysterious', 'of', 'seem', 'the'],
#  'towards': ['acted', 'advancing', 'affection', 'although', 'and'],
#  'advancing,': ['am', 'appear', 'are', 'gives'],
#  'gives': ['a', 'advancing,', 'and', 'ariosto', 'concerning'],
#  'foretaste': ['a', 'of'],
#  'those': ['all', 'all', 'all', 'among', 'among'],
#  'icy': ['and', 'climes.', 'the', 'their', 'those'],
#  'climes.': ['icy', 'inspirited'],
#  'inspirited': ['and', 'and', 'by', 'by', 'climes.'],
#  'wind': ['among', 'and', 'arose', 'arose;', 'as'],
#  'promise,': ['my', 'of', 'rose', 'unhappy'],
#  'daydreams': ['are', 'become', 'my', 'my'],
#  'become': ['a', 'a', 'a', 'a', 'acquainted'],
#  'more': ['(i', 'a', 'a', 'a', 'a'],
#  'fervent': ['a', 'and', 'longing', 'more'],
#  'vivid.': ['and', 'i'],
#  'try': ['i', 'in', 'in', 'our', 'to'],
#  'vain': ['and', 'be', 'endeavour', 'endeavour', 'for'],
#  'be': ['(i', '_to', 'a', 'a', 'a'],
#  'persuaded': ['(i', 'be', 'have', 'have', 'him'],
#  'pole': ['is', 'the', 'the', 'to'],
#  'seat': ['a', 'of', 'of', 'the', 'the'],
#  'frost': ['and', 'and', 'and', 'are', 'by'],
#  'desolation;': ['and', 'create', 'his', 'i', 'it'],
#  'ever': ['acting', 'again', 'alive', 'am', 'and'],
#  'presents': ['a', 'ever', 'indeed,', 'itself', 'itself'],
#  'itself': ['and', 'became', 'behind', 'confine', 'declare'],
#  'imagination': ['a', 'and', 'ardent', 'as', 'conjured'],
#  'region': ['every', 'he', 'hitherto', 'of', 'the'],
#  'beauty': ['and', 'and', 'and', 'and', 'and'],
#  'there,': ['alive', 'be', 'but', 'delight.', 'did'],
#  'margaret,': ['dear', 'dear', 'do', 'god!', 'if'],
#  'sun': ['and', 'and', 'and', 'became', 'became'],
#  'visible,': ['ever', 'its', 'nor', 'still', 'was'],
#  'its': ['agitated', 'alarm,', 'all', 'all', 'amidst'],
#  'broad': ['disk', 'disk', 'its', 'the'],
#  'disk': ['broad', 'broad', 'damaged', 'just', 'of'],
#  'just': ['a', 'air', 'am', 'at', 'at'],
#  'skirting': ['just', 'the'],
#  'horizon': ['and', 'as', 'the', 'the', 'the'],
#  'diffusing': ['a', 'and'],
#  'perpetual': ['a', 'a', 'astonishment,', 'attention', 'but'],
#  'splendour.': ['perpetual', 'there—for'],
#  'there—for': ['splendour.', 'with'],
#  'your': ['abhorrence', 'ability,', 'absence,', 'absence.”', 'accept'],
#  'leave,': ['my', 'your'],
#  'sister,': ['and', 'and', 'beloved', 'beloved', 'brother,'],
#  'put': ['accordingly', 'accordingly', 'aim,', 'all', 'an'],
#  'some': ['1.f.5.', 'accident', 'accomplish', 'acquaintances,', 'after'],
#  'trust': ['but', 'him', 'i', 'in', 'myself'],
#  'preceding': ['day', 'flash.', 'in', 'navigators—there', 'night,'],
#  'navigators—there': ['preceding', 'snow'],
#  'snow': ['and', 'and', 'and', 'and', 'and'],
#  'banished;': ['and,', 'are'],
#  'and,': ['after', 'among', 'as', 'as', 'banished;'],
#  'sailing': ['and,', 'over'],
#  'over': ['a', 'and', 'and', 'bent', 'bent'],
#  'calm': ['a', 'a', 'and', 'and', 'and'],
#  'sea,': ['and', 'and', 'and', 'but', 'calm'],
#  'we': ['2', '31st)', '8', 'accordingly', 'accordingly'],
#  'wafted': ['am', 'be', 'breeze', 'it', 'the'],
#  'land': ['a', 'a', 'and', 'at', 'by'],
#  'surpassing': ['in', 'land', 'loveliness', 'the'],
#  'wonders': ['and', 'in', 'new', 'of', 'the'],
#  'every': ['aggravation', 'aid', 'almost', 'almost', 'altered'],
#  'hitherto': ['attended', 'been', 'been', 'been', 'been'],
#  'discovered': ['also', 'and', 'and', 'and', 'been'],
#  'on': ['7', '_campagne_', 'a', 'a', 'a'],
#  'habitable': ['globe.', 'the'],
#  'globe.': ['habitable', 'its'],
#  'productions': ['and', 'its', 'of', 'the'],
#  'features': ['and', 'appeared', 'as', 'distorted', 'half'],
#  'without': ['a', 'a', 'again', 'and', 'any'],
#  'example,': ['as', 'how', 'my', 'without'],
#  'phenomena': ['of', 'the', 'the', 'which'],
#  'heavenly': ['and', 'bodies', 'scene', 'that', 'the'],
#  'bodies': ['deprived', 'had', 'heavenly', 'of', 'opaque'],
#  'undoubtedly': ['are', 'bodies'],
#  'undiscovered': ['island,', 'solitudes.', 'some', 'those'],
#  'solitudes.': ['undiscovered', 'what'],
#  'what': ['a', 'a', 'a', 'a', 'a'],
#  'expected': ['a', 'be', 'friend', 'from', 'humour'],
#  'eternal': ['an', 'and', 'dead;', 'frosts.', 'grief'],
#  'light?': ['eternal', 'i'],
#  'there': ['a', 'affection.', 'again', 'agreement.', 'all'],
#  'discover': ['a', 'and', 'any', 'from', 'him'],
#  'wondrous': ['and', 'and', 'cave', 'nature', 'power'],
#  'power': ['a', 'a', 'and', 'and', 'and'],
#  'attracts': ['the', 'which'],
#  'needle': ['and', 'the'],
#  'regulate': ['a', 'may', 'my', 'to'],
#  'thousand': ['a', 'a', 'a', 'a', 'a'],
#  'celestial': ['a', 'a', 'and', 'eyes,', 'her'],
#  'observations': ['celestial', 'that'],
#  'require': ['must', 'only', 'such', 'that'],
#  'only': ['a', 'a', 'a', 'a', 'a'],
#  'voyage': ['a', 'a', 'and', 'came', 'from'],
#  'render': ['and', 'blanc,', 'her', 'him', 'man'],
#  'their': ['_acme_,', 'account', 'actions.', 'admire', 'after'],
#  'seeming': ['earnestness', 'eccentricities', 'their', 'with'],
#  'eccentricities': ['consistent', 'seeming'],
#  'consistent': ['eccentricities', 'for'],
#  'ever.': ['a', 'and', 'are', 'at', 'but'],
#  'shall': ['accompany', 'again', 'again', 'again', 'agreement'],
#  'satiate': ['my', 'shall'],
#  'ardent': ['affections,', 'an', 'and', 'and', 'and'],
#  'curiosity': ['and', 'and', 'and', 'and', 'and'],
#  'sight': ['a', 'afforded', 'every', 'first', 'lose'],
#  'part': ['a', 'a', 'a', 'a', 'a'],
#  'never': ['again', 'again', 'alluded', 'and', 'and'],
#  'visited,': ['and', 'before'],
#  'tread': ['a', 'and', 'may', 'the'],
#  'imprinted': ['before', 'by', 'i', 'the'],
#  'foot': ['against', 'her', 'his', 'my', 'of'],
#  'man.': ['a', 'alas!', 'as', 'as', 'as'],
#  'these': ['advantages,', 'all', 'all', 'all', 'also;'],
#  'enticements,': ['and', 'my'],
#  'they': ['abhorred!', 'accordingly', 'affection.', 'after', 'agreed'],
#  'sufficient': ['air', 'allurements', 'are', 'beauty', 'courage'],
#  'conquer': ['all', 'to'],
#  'all': ['50', '_honour_,', 'a', 'about', 'above'],
#  'fear': ['again', 'all', 'all', 'and', 'and'],
#  'danger': ['and', 'because', 'continual', 'even', 'for'],
#  'death': ['a', 'and', 'and', 'and', 'and'],
#  'induce': ['me', 'poor', 'to', 'to', 'to'],
#  'commence': ['a', 'a', 'and', 'his', 'i'],
#  'laborious': ['and', 'disquisition.', 'occupations', 'this', 'various'],
#  'joy': ['a', 'all', 'and', 'and', 'and'],
#  'child': ['a', 'a', 'a', 'a', 'a'],
#  'feels': ['child', 'when'],
#  'when': ['3', 'a', 'a', 'a', 'absent'],
#  'he': ['accumulated', 'addressed', 'admiration,', 'adventure.', 'affection.'],
#  'embarks': ['he', 'in'],
#  'little': ['_wives,_', 'a', 'a', 'a', 'a'],
#  'boat,': ['a', 'and', 'his', 'little', 'little'],
#  'his': ['abandoned', 'abhorred', 'abode.', 'acceptance.', 'advice'],
#  'holiday': ['his', 'mates,'],
#  'mates,': ['holiday', 'on'],
#  'expedition': ['an', 'has', 'of', 'this', 'this'],
#  'discovery': ['a', 'and', 'composed', 'for', 'if'],
#  'up': ['a', 'an', 'and', 'and', 'and'],
#  'native': ['a', 'a', 'can', 'country', 'country'],
#  'river.': ['but', 'native'],
#  'but': ['_wives,_', 'a', 'a', 'a', 'a'],
#  'supposing': ['all', 'but', 'help', 'that'],
#  'conjectures': ['these', 'to'],
#  'false,': ['be', 'you'],
#  'cannot': ['abhorrence', 'absence', 'and', 'and', 'and'],
#  'contest': ['cannot', 'the'],
#  'inestimable': ['benefit', 'the'],
#  'benefit': ['every', 'inestimable', 'little', 'of', 'the'],
#  'confer': ['on', 'shall'],
#  'mankind,': ['all', 'among', 'and', 'to'],
#  'last': ['at', 'at', 'autumn', 'autumn.', 'banker,'],
#  'generation,': ['by', 'last'],
#  'discovering': ['a', 'by', 'in', 'on', 'that'],
#  'passage': ['a', 'a', 'be', 'free', 'in'],
#  'near': ['a', 'a', 'a', 'alpine', 'and'],
#  'countries,': ['those', 'to'],
#  'reach': ['england', 'my', 'never', 'should', 'the'],
#  'present': ['at', 'at', 'at', 'at', 'at'],
#  'so': ['(for', '17—.', 'acuteness', 'after', 'after'],
#  'many': ['a', 'admirable', 'after', 'ages.', 'alone.'],
#  'months': ['after', 'after', 'ago,', 'and', 'are'],
#  'requisite;': ['are', 'or'],
#  'ascertaining': ['by', 'the'],
#  'secret': ['a', 'a', 'dreadful', 'from', 'my'],
#  'magnet,': ['the', 'which,'],
#  'which,': ['after', 'alterations,', 'although', 'although', 'an'],
#  'possible,': ['all', 'as', 'can', 'that', 'the'],
#  'can': ['afford.', 'alleviate;', 'alloy', 'alone', 'alone'],
#  'effected': ['be', 'by'],
#  'undertaking': ['a', 'an', 'an', 'and', 'from'],
#  'mine.': ['as', 'i', 'in', 'these', 'to'],
#  'reflections': ['as', 'determined', 'during', 'during', 'have'],
#  'dispelled': ['have', 'the'],
#  'agitation': ['an', 'and', 'as', 'extreme', 'for'],
#  'began': ['again', 'again', 'almost', 'also', 'also'],
#  'letter,': ['and', 'and', 'her', 'my', 'the'],
#  'heart': ['a', 'and', 'and', 'and', 'and'],
#  'glow': ['heart', 'with'],
#  'enthusiasm': ['an', 'first', 'for,', 'i', 'mad'],
#  'elevates': ['him', 'me', 'that', 'which'],
#  'heaven,': ['and', 'and', 'as', 'by', 'by'],
#  'nothing': ['9', 'alighting!”', 'and', 'apparatus.', 'appeared.'],
#  'contributes': ['nothing', 'so'],
#  'much': ['admired,', 'after', 'altered', 'and', 'applied'],
#  'tranquillise': ['the', 'to'],
#  'mind': ['a', 'a', 'a', 'and', 'and'],
#  'steady': ['a', 'be', 'purpose—a', 'to'],
#  'purpose—a': ['point', 'steady'],
#  'point': ['a', 'and', 'and', 'every', 'he'],
#  'soul': ['a', 'a', 'all', 'and', 'and'],
#  'fix': ['its', 'may', 'the', 'the', 'the'],
#  'intellectual': ['and', 'eye.', 'its', 'other', 'property'],
#  'eye.': ['[wordsworth’s', 'intellectual', 'the', 'this'],
#  'been': ['a', 'a', 'a', 'a', 'a'],
#  'favourite': ['a', 'authors,', 'companion', 'dream', 'employment.'],
#  'dream': ['a', 'a', 'a', 'airy', 'and'],
#  'early': ['an', 'an', 'and', 'childhood;', 'date,'],
#  'years.': ['as', 'childish', 'declining', 'during', 'earlier'],
#  'read': ['aloud,', 'and', 'and', 'and', 'and'],
#  'ardour': ['an', 'burning', 'for', 'fresh', 'greater'],
#  'accounts': ['of', 'of', 'of', 'the', 'the'],
#  'various': ['arguments', 'arguments', 'arguments', 'arts', 'awakened'],
#  'voyages': ['little', 'made', 'of', 'the', 'various'],
#  'made': ['a', 'a', 'a', 'a', 'a'],
#  'prospect': ['did', 'near', 'of', 'of', 'of'],
#  'arriving': ['at', 'of'],
#  'pacific': ['north', 'ocean'],
#  'ocean': ['appeared', 'he', 'of', 'of', 'pacific'],
#  'through': ['1.e.1', '1.e.1', '1.e.7', '1.e.7', 'a'],
#  'seas': ['desert', 'i', 'rather', 'the', 'the'],
#  'surround': ['her', 'it', 'it.', 'that', 'that'],
#  'pole.': ['northern', 'the', 'upon', 'you'],
#  'remember': ['condescension.', 'due.', 'ever', 'i', 'i'],
#  'history': ['a', 'and', 'and', 'and', 'briefly'],
#  'purposes': ['and', 'effect', 'for', 'of', 'of'],
#  'composed': ['be', 'discovery', 'he', 'heroic', 'more'],
#  'whole': ['authority', 'being', 'countenance', 'day', 'day,'],
#  'our': ['about', 'actions', 'admiration.', 'after', 'after'],
#  'good': ['a', 'a', 'a', 'and', 'and'],
#  'uncle': ['and', 'dated', 'from', 'good', 'her'],
#  'thomas’': ['books', 'library.', 'uncle', 'uncle'],
#  'library.': ['my', 'thomas’'],
#  'education': ['an', 'in', 'my', 'my', 'my'],
#  'was': ['_father._', '_he_', '_i_', 'a', 'a'],
#  'neglected,': ['but', 'not', 'was', 'yet'],
#  'yet': ['a', 'a', 'actions.', 'affection,', 'alive'],
#  'passionately': ['fond', 'was'],
#  'fond': ['and', 'embrace', 'fancy', 'my', 'of'],
#  'reading.': ['of', 'these'],
#  'volumes': ['other', 'these', 'were', 'which'],
#  'were': ['a', 'a', 'a', 'accumulated', 'affectionate'],
#  'study': ['and', 'and', 'and', 'appertaining', 'as'],
#  'day': ['18', 'a', 'a', 'a', 'additional'],
#  'night,': ['already', 'and', 'and', 'and', 'and'],
#  'familiarity': ['my', 'with'],
#  'them': ['a', 'a', 'accompanied', 'accompanied', 'accompany'],
#  'increased': ['cold', 'comfort', 'daily', 'enemy', 'every'],
#  'regret': ['and', 'i', 'in', 'might', 'our'],
#  'had': ['(i', 'a', 'a', 'a', 'a'],
#  'felt,': ['and', 'and', 'as', 'had', 'have'],
#  'child,': ['a', 'beautiful', 'better—their', 'but', 'eldest'],
#  'learning': ['on', 'that'],
#  'father’s': ['account,', 'advanced', 'age', 'care', 'consent'],
#  'dying': ['away', 'father’s', 'injunction', 'moments', 'my'],
#  'injunction': ['dying', 'had'],
#  'forbidden': ['are', 'had', 'my', 'spirit', 'to'],
#  'allow': ['beds,', 'but', 'disclaimers', 'dæmon,', 'her'],
#  'embark': ['in', 'to'],
#  'seafaring': ['a', 'life.'],
#  'life.': ['and', 'chapter', 'given', 'given', 'her'],
#  'visions': ['bright', 'faded', 'of', 'of', 'on'],
#  'faded': ['visions', 'when'],
#  'perused,': ['for', 'i'],
#  'time,': ['also,', 'and', 'but', 'but', 'but'],
#  'poets': ['celebrated', 'of', 'those', 'whose'],
#  'whose': ['aerial', 'alps,', 'and', 'and', 'and'],
#  'effusions': ['entranced', 'whose'],
#  'entranced': ['effusions', 'my'],
#  'lifted': ['and', 'it'],
#  'heaven.': ['i', 'to'],
#  'also': ['a', 'a', 'am', 'and', 'another'],
#  'became': ['a', 'a', 'a', 'a', 'accustomed'],
#  'poet': ['a', 'and'],
#  'one': ['a', 'a', 'above;', 'already', 'among'],
#  'year': ['a', 'a', 'a', 'ago,', 'difference'],
#  'lived': ['again', 'already', 'for', 'had', 'had'],
#  'paradise': ['a', 'a', 'compared', 'of'],
#  'own': ['agitation', 'apartment.', 'auditor.', 'beautiful', 'behaviour'],
#  'creation;': ['filthy', 'i', 'my', 'own', 'the'],
#  'imagined': ['and', 'be', 'have', 'himself', 'i'],
#  'might': ['accident', 'accidents', 'adventurer', 'afford', 'afford'],
#  'obtain': ['a', 'a', 'absolution;', 'food', 'may'],
#  'niche': ['a', 'in'],
#  'temple': ['the', 'where'],
#  'names': ['adored', 'and', 'and', 'are', 'filled'],
#  'homer': ['and', 'of'],
#  'shakespeare': ['and', 'are'],
#  'consecrated.': ['are', 'you'],
#  'well': ['accorded', 'acquainted', 'acquainted', 'acquainted', 'acquainted'],
#  'acquainted': ['appeared', 'became', 'became', 'became', 'become'],
#  'failure': ['and', 'my', 'rather', 'the'],
#  'how': ['17—.', 'alas,', 'all', 'all', 'altered'],
#  'heavily': ['and', 'how', 'i', '“how'],
#  'bore': ['a', 'a', 'and', 'arch-fiend,', 'i'],
#  'disappointment.': ['but', 'but', 'dæmon’s', 'he', 'of'],
#  'time': ['(although', 'a', 'a', 'a', 'a'],
#  'inherited': ['i', 'the', 'the', 'worm'],
#  'fortune': ['and', 'could', 'good', 'good', 'in'],
#  'cousin,': ['and', 'dear', 'dearest', 'how', 'i'],
#  'thoughts': ['and', 'and', 'and', 'and', 'befitting'],
#  'turned': ['_you_', 'adrift,', 'are', 'away', 'easily'],
#  'into': ['a', 'a', 'a', 'a', 'a'],
#  'channel': ['of', 'the'],
#  'earlier': ['bent.', 'in', 'my', 'their', 'years.'],
#  'bent.': ['earlier', 'six'],
#  'six': ['bent.', 'boyhood.', 'nearly', 'rising.', 'years'],
#  'years': ['after', 'ago', 'ago,', 'ago,', 'ago,'],
#  'passed': ['a', 'a', 'a', 'a', 'a'],
#  'since': ['altered', 'and', 'and', 'been', 'but'],
#  'resolved': ['and', 'and', 'and', 'day', 'every'],
#  'can,': ['and', 'even', 'i', 'you'],
#  'even': ['_you_', 'a', 'affecting', 'affection', 'after'],
#  'now,': ['and', 'and', 'and', 'and', 'as'],
#  'hour': ['accustomed', 'afterwards', 'an', 'an', 'an'],
#  'dedicated': ['had', 'i', 'myself', 'myself;'],
#  'myself': ['a', 'a', 'a', 'absent', 'acquitted'],
#  'great': ['a', 'a', 'a', 'a', 'a'],
#  'enterprise.': ['great', 'great', 'he', 'i', 'i'],
#  'commenced': ['an', 'by', 'i', 'i', 'my'],
#  'inuring': ['by', 'my'],
#  'body': ['and', 'and', 'and', 'could', 'dreadfully'],
#  'hardship.': ['i', 'to'],
#  'whale-fishers': ['on', 'the'],
#  'several': ['accidents,', 'and', 'articles', 'beautiful', 'books'],
#  'expeditions': ['several', 'to'],
#  'sea;': ['i', 'i', 'i', 'it', 'it'],
#  'voluntarily': ['endured', 'i'],
#  'endured': ['all', 'be', 'cold,', 'family', 'for'],
#  'cold,': ['and', 'and', 'and', 'by', 'endured'],
#  'famine,': ['cold,', 'thirst,'],
#  'thirst,': ['a', 'a', 'and', 'and', 'and'],
#  'want': ['(as', 'a', 'and', 'and', 'and'],
#  'sleep;': ['but', 'i', 'of', 'profound'],
#  'often': ['and', 'and', 'and', 'are', 'are'],
#  'worked': ['been', 'degrees', 'had', 'hard', 'harder'],
#  'harder': ['than', 'worked'],
#  'than': ['"plain', 'a', 'a', 'a', 'a'],
#  'common': ['a', 'and', 'language', 'of', 'pathways'],
#  'sailors': ['are', 'as', 'busy', 'common', 'during'],
#  'during': ['a', 'abroad', 'accustomed,', 'adversary.', 'afflicted.'],
#  'devoted': ['affection,', 'affection.', 'and', 'and', 'apparently'],
#  'nights': ['and', 'and', 'clear', 'in', 'my'],
#  'mathematics,': ['of', 'the'],
#  'theory': ['a', 'and', 'of', 'the', 'the'],
#  'medicine,': ['and', 'of'],
#  'branches': ['above', 'different', 'of', 'of', 'of'],
#  'physical': ['a', 'a', 'debility', 'medium', 'medium,'],
#  'science': ['a', 'and', 'and', 'and', 'and'],
#  'naval': ['a', 'adventurer'],
#  'adventurer': ['might', 'naval'],
#  'derive': ['from', 'its', 'might', 'the', 'to'],
#  'greatest': ['affability', 'affection', 'affection.', 'agitation,', 'ardour'],
#  'practical': ['advantage.', 'greatest', 'their', 'uses.'],
#  'advantage.': ['practical', 'twice'],
#  'twice': ['advantage.', 'i', 'i', 'or'],
#  'actually': ['freezing', 'from', 'hired', 'i'],
#  'hired': ['a', 'a', 'a', 'a', 'actually'],
#  'under-mate': ['an', 'in'],
#  'greenland': ['a', 'whaler,'],
#  'whaler,': ['and', 'greenland'],
#  'acquitted': ['and', 'myself'],
#  'admiration.': ['and', 'and', 'but', 'i', 'our'],
#  'must': ['absent', 'also', 'and', 'and', 'appear'],
#  'felt': ['a', 'a', 'a', 'a', 'a'],
#  'proud': ['a', 'and', 'little', 'when'],
#  'captain': ['my', 'offered', 'perceive,', 'to', 'walton,'],
#  'offered': ['captain', 'communication,', 'me', 'the'],
#  'second': ['a', 'a', 'a', 'copy', 'dignity'],
#  'dignity': ['and', 'certain', 'in', 'in', 'of'],
#  'vessel': ['a', 'a', 'a', 'a', 'and'],
#  'entreated': ['and', 'earnestly', 'feet,', 'he', 'he'],
#  'remain': ['a', 'a', 'a', 'alone.', 'as'],
#  'earnestness,': ['greatest', 'so'],
#  'valuable': ['did', 'miniature', 'so', 'very'],
#  'did': ['(i', 'a', 'accused', 'and', 'and'],
#  'consider': ['and', 'he', 'i', 'it', 'my'],
#  'services.': ['and', 'his', 'i', 'my'],
#  'deserve': ['not', 'should', 'theirs.', 'to'],
#  'accomplish': ['and', 'some', 'that', 'to'],
#  'purpose?': ['great', 'my'],
#  'life': ['alas!', 'among', 'and', 'and', 'and'],
#  'ease': ['and', 'in', 'the', 'to'],
#  'luxury,': ['and', 'but'],
#  'preferred': ['glory', 'i'],
#  'glory': ['and', 'and', 'antique', 'for', 'of'],
#  'enticement': ['every', 'that'],
#  'wealth': ['and', 'and', 'and', 'attention.', 'his'],
#  'placed': ['a', 'and', 'and', 'and', 'and'],
#  'path.': ['i', 'my', 'my', 'my', 'oh,'],
#  'oh,': ['close!', 'creature.', 'earth!', 'frankenstein!', 'frankenstein,'],
#  'encouraging': ['some', 'voice'],
#  'voice': ['a', 'a', 'a', 'a', 'accompanied'],
#  'would': ['account', 'again', 'allow', 'alone', 'alone'],
#  'answer': ['a', 'an', 'and', 'cannot', 'constant'],
#  'affirmative!': ['my', 'the'],
#  'courage': ['and', 'and', 'and', 'and', 'and'],
#  'resolution': ['a', 'a', 'first', 'gathered', 'i'],
#  'firm;': ['but', 'is'],
#  'hopes': ['and', 'and', 'and', 'and', 'and'],
#  'fluctuate,': ['and', 'hopes'],
#  'spirits': ['and', 'and', 'and', 'are', 'be'],
#  'depressed.': ['i', 'often'],
#  'about': ['"information', 'a', 'a', 'a', 'a'],
#  'proceed': ['might', 'on', 'over', 'should', 'southwards'],
#  'long': ['a', 'a', 'a', 'a', 'a'],
#  'difficult': ['and', 'it', 'to', 'voyage,'],
#  'voyage,': ['difficult', 'he', 'longer', 'the'],
#  'emergencies': ['of', 'the'],
#  'demand': ['a', 'a', 'all', 'an', 'i'],
#  'fortitude:': ['i', 'my'],
#  'required': ['am', 'hardly', 'him', 'i', 'i'],
#  'raise': ['again', 'me', 'my', 'my', 'the'],
#  'others,': ['among', 'at', 'at', 'but', 'declined'],
#  'sometimes': ['admiration.', 'and', 'and', 'and', 'and'],
#  'sustain': ['hardly', 'me', 'my', 'not', 'not'],
#  'own,': ['her', 'my', 'my', 'she', 'to'],
#  'theirs': ['are', 'when'],
#  'failing.': ['are', 'this'],
#  'favourable': ['a', 'a', 'a', 'a', 'eye'],
#  'period': ['a', 'appear', 'approached,', 'at', 'considerable'],
#  'travelling': ['for', 'in'],
#  'russia.': ['in', 'they'],
#  'fly': ['far', 'from', 'from', 'from', 'from'],
#  'quickly': ['and', 'and', 'and', 'and', 'and'],
#  'sledges;': ['the', 'their'],
#  'motion': ['agitated', 'among', 'convulsive', 'is', 'of'],
#  'pleasant,': ['and,', 'is'],
#  'opinion,': ['and', 'far', 'my', 'same'],
#  'agreeable': ['an', 'an', 'aspect', 'asylum', 'more'],
#  'stagecoach.': ['english', 'the'],
#  'excessive,': ['and', 'if', 'is', 'not'],
#  'wrapped': ['are', 'him', 'in', 'solely', 'up'],
#  'furs—a': ['dress', 'in'],
#  'dress': ['and', 'and', 'furs—a', 'my', 'my'],
#  'adopted,': ['already', 'for'],
#  'difference': ['between', 'between', 'considerable', 'great', 'in'],
#  'between': ['barrier', 'boundary', 'community', 'conclusion.', 'confidence'],
#  'walking': ['about.', 'and', 'between', 'continued', 'health,'],
#  'deck': ['and', 'and', 'and', 'looking', 'on'],
#  'remaining': ['and', 'and', 'friends', 'friends.”', 'in'],
#  'seated': ['and', 'in', 'motionless', 'myself', 'remaining'],
#  'motionless': ['and', 'for', 'hours', 'seated'],
#  'hours,': ['and', 'for', 'of', 'rather', 'several'],
#  'exercise': ['and', 'and', 'bodily', 'bodily', 'no'],
#  'prevents': ['exercise', 'improvement', 'sorrow', 'the'],
#  'blood': ['and', 'boils', 'circulates,', 'congeal', 'did'],
#  'freezing': ['actually', 'in'],
#  'veins.': ['i', 'your'],
#  'ambition': ['and', 'no', 'of', 'of', 'that'],
#  'lose': ['again', 'all', 'and', 'him.', 'i'],
#  'post-road': ['between', 'the'],
#  'petersburgh': ['and', 'st.'],
#  'archangel.': ['and', 'i'],
#  'depart': ['again.', 'for', 'for', 'i', 'i'],
#  'latter': ['city', 'days', 'end', 'end', 'method'],
#  'town': ['a', 'about', 'and', 'and', 'and'],
#  'fortnight': ['a', 'a', 'a', 'after', 'another'],
#  'three': ['and', 'been', 'but', 'come', 'days'],
#  'weeks;': ['and', 'three'],
#  'intention': ['hellish', 'is', 'my', 'of'],
#  'hire': ['a', 'to'],
#  'ship': ['a', 'for', 'on', 'the', 'the'],
#  'easily': ['be', 'be', 'be', 'be', 'believe,”'],
#  'done': ['a', 'be', 'before.', 'by', 'by'],
#  'paying': ['any', 'by', 'copyright', 'including', 'royalties'],
#  'insurance': ['for', 'the'],
#  'owner,': ['and', 'and', 'any', 'the', 'trademark'],
#  'engage': ['as', 'him.', 'should', 'to', 'to'],
#  'think': ['affections,', 'and', 'and', 'being.', 'hereafter'],
#  'necessary': ['all', 'among', 'before', 'beings.', 'explanation'],
#  'among': ['admiration', 'aged', 'and', 'and,', 'archangel,'],
#  'who': ['abhor', 'acquaintances,', 'agatha,', 'agree', 'aided'],
#  'accustomed': ['are', 'are', 'became', 'hour', 'my'],
#  'whale-fishing.': ['i', 'the'],
#  'intend': ['not', 'not', 'not', 'not', 'to'],
#  'sail': ['another', 'directly', 'in', 'may', 'should'],
#  'until': ['a', 'affection', 'at', 'attempt', 'broken'],
#  'month': ['a', 'a', 'after', 'her', 'of'],
#  'june;': ['and', 'of'],
#  'return?': ['ah,', 'i'],
#  'ah,': ['dear', 'return?'],
#  'question?': ['if', 'this'],
#  'succeed,': ['i', 'many,'],
#  'many,': ['many', 'succeed,'],
#  'months,': ['and', 'as', 'calm', 'few', 'many'],
#  'perhaps': ['also', 'and', 'and', 'and', 'and'],
#  'years,': ['and', 'for', 'forty', 'he', 'many'],
#  'pass': ['away;', 'before', 'before', 'continually', 'could'],
#  'meet.': ['explanation!', 'how', 'if', 'may', 'to'],
#  'fail,': ['i', 'you'],
#  'see': ['a', 'a', 'a', 'again', 'agreement.'],
#  'again': ['accident', 'allowed', 'alone,', 'and', 'and'],
#  'soon,': ['again', 'close.', 'oh,', 'or', 'very'],
#  'never.': ['farewell,', 'or'],
#  'farewell,': ['arms.', 'behold.', 'frankenstein!', 'my', 'never.'],
#  'dear,': ['dear', 'excellent', 'my', 'so', 'so'],
#  'excellent': ['an', 'an', 'an', 'and', 'and'],
#  'margaret.': ['be', 'dear', 'excellent', 'heaven'],
#  'heaven': ['and', 'and', 'bless', 'bless', 'finish.'],
#  'shower': ['down', 'heaven'],
#  'down': ['a', 'a', 'advancing', 'among', 'and'],
#  'blessings': ['and', 'down', 'on', 'with'],
#  'you,': ['agitates', 'alone?', 'and', 'and', 'and'],
#  'save': ['all,', 'and', 'and', 'any', 'could'],
#  'me,': ['abandoned', 'addressed', 'addressed', 'affected', 'against'],
#  'testify': ['again', 'my'],
#  'gratitude': ['and', 'and', 'assisted', 'at', 'feel'],
#  'love': ['a', 'a', 'a', 'additional', 'and'],
#  'kindness.': ['and', 'and', 'and', 'and', 'extreme'],
#  'affectionate': ['and', 'brother,', 'brother,', 'most', 'mother.'],
#  'brother,': ['a', 'affectionate', 'affectionate', 'and', 'and'],
#  'r.': ['brother,', 'walton'],
#  'walton': ['letter', 'letter', 'r.', 'robert'],
#  'archangel,': ['28th', 'among', 'england._', 'in'],
#  '28th': ['archangel,', 'march,'],
#  'march,': ['17—.', '28th', 'i', 'toilsome'],
#  'slowly': ['coming', 'how', 'in', 'the'],
#  'passes': ['here,', 'over', 'that', 'time'],
#  'here,': ['and', 'dwelling', 'encompassed', 'for', 'health.'],
#  'encompassed': ['as', 'be', 'by', 'by', 'here,'],
#  'snow!': ['and', 'yet'],
#  'step': ['even', 'every', 'first', 'huge', 'in'],
#  'taken': ['am', 'among', 'an', 'be', 'been'],
#  'occupied': ['a', 'again', 'am', 'artist', 'as'],
#  'collecting': ['a', 'and', 'in', 'in', 'in'],
#  'sailors;': ['my', 'those'],
#  'whom': ['all', 'and', 'and', 'and', 'angel,'],
#  'engaged': ['already', 'appear', 'continually', 'deeply', 'easily'],
#  'appear': ['advancing,', 'confused', 'could', 'dimples', 'engaged'],
#  'men': ['all', 'all', 'and', 'and', 'appear'],
#  'depend': ['and', 'can', 'to', 'too'],
#  'certainly': ['acted', 'am', 'are', 'as', 'as'],
#  'possessed': ['a', 'a', 'a', 'a', 'a'],
#  'dauntless': ['and', 'courage,', 'courage.', 'of'],
#  'courage.': ['but', 'dauntless', 'of', 'when'],
#  'able': ['as', 'been', 'being', 'being', 'being'],
#  'satisfy,': ['and', 'to'],
#  'absence': ['cannot', 'i', 'misfortune?', 'my', 'my'],
#  'object': ['already', 'an', 'an', 'an', 'chief'],
#  'now': ['a', 'about', 'accustomed', 'affirm', 'again'],
#  'severe': ['a', 'evil,', 'most', 'to', 'tone,'],
#  'evil,': ['and', 'benevolence', 'distant', 'i', 'irreparable'],
#  'friend,': ['a', 'a', 'a', 'a', 'and'],
#  'margaret:': ['friend,', 'when'],
#  'glowing': ['am', 'with'],
#  'success,': ['and', 'my', 'of', 'such', 'there'],
#  'none': ['alone;', 'among', 'and', 'and', 'be'],
#  'participate': ['in', 'my', 'not', 'to'],
#  'joy;': ['and', 'but', 'i', 'if', 'like'],
#  'assailed': ['am', 'by'],
#  'disappointment,': ['by', 'no'],
#  'endeavour': ['again', 'and', 'and', 'and', 'to'],
#  'dejection.': ['i', 'in', 'in', 'lowest'],
#  'commit': ['my', 'my', 'shall', 'some', 'still'],
#  'paper,': ['it', 'to'],
#  'true;': ['but', 'is'],
#  'poor': ['a', 'a', 'affection.', 'am', 'and'],
#  'medium': ['and', 'for', 'on', 'physical', 'poor'],
#  'communication': ['little', 'of', 'the', 'with'],
#  'feeling.': ['after', 'i', 'of', 'other'],
#  'desire': ['a', 'a', 'a', 'a', 'against'],
#  'company': ['and', 'another’s', 'of', 'of', 'of'],
#  'man': ['a', 'a', 'a', 'a', 'a'],
#  'could': ['accident', 'afford.', 'always', 'and', 'and'],
#  'sympathise': ['and', 'could', 'not', 'with', 'with'],
#  'eyes': ['aching', 'and', 'and', 'and', 'and'],
#  'reply': ['to', 'would'],
#  'deem': ['may', 'me'],
#  'romantic,': ['and', 'as', 'me', 'my'],
#  'bitterly': ['and', 'deplored', 'feel', 'he', 'i'],
#  'friend.': ['a', 'admirable', 'and', 'but', 'his'],
#  'gentle': ['a', 'a', 'a', 'a', 'agatha,'],
#  'courageous,': ['possessed', 'yet'],
#  'cultivated': ['a', 'and', 'as', 'the'],
#  'capacious': ['a', 'mind,'],
#  'mind,': ['and', 'and', 'and', 'but', 'capacious'],
#  'tastes': ['are', 'for', 'my', 'whose'],
#  'like': ['a', 'a', 'a', 'a', 'a'],
#  'approve': ['highly', 'or', 'should', 'to'],
#  'amend': ['my', 'or'],
#  'plans.': ['he', 'how', 'my', 'other'],
#  'friend': ['a', 'a', 'a', 'and', 'and'],
#  'repair': ['friend', 'the'],
#  'faults': ['of', 'the'],
#  'brother!': ['i', 'poor'],
#  'too': ['a', 'agitation', 'almost', 'almost', 'am'],
#  'execution': ['and', 'in', 'of', 'of', 'of'],
#  'impatient': ['if', 'my', 'of', 'of', 'thirst'],
#  'difficulties.': ['but', 'insurmountable', 'of', 'sometimes,'],
#  'still': ['a', 'a', 'a', 'abhor.', 'alive'],
#  'greater': ['a', 'a', 'a', 'a', 'a'],
#  'self-educated:': ['am', 'for'],
#  'fourteen': ['first', 'years'],
#  'ran': ['across', 'and', 'by', 'down', 'from'],
#  'wild': ['a', 'a', 'a', 'and', 'and'],
#  'books': ['and', 'by', 'i', 'in', 'in'],
#  'voyages.': ['at', 'of'],
#  'age': ['advanced', 'and', 'father’s', 'i', 'of'],
#  'celebrated': ['and', 'city.', 'poets', 'the'],
#  'country;': ['a', 'again', 'beloved', 'but', 'but'],
#  'ceased': ['and', 'for', 'had', 'had', 'had'],
#  'important': ['benefits', 'most', 'particularly', 'to'],
#  'benefits': ['from', 'important'],
#  'conviction': ['a', 'forced', 'greater', 'in', 'my'],
#  'perceived': ['a', 'a', 'a', 'and', 'be'],
#  'necessity': ['began', 'immediate', 'imposed', 'of', 'the'],
#  'becoming': ['acquainted', 'acquainted', 'acquainted,', 'in', 'of'],
#  'languages': ['engaged', 'more', 'sanskrit', 'than'],
#  'country.': ['a', 'at', 'he', 'his', 'i'],
#  'twenty-eight': ['am', 'and'],
#  'reality': ['came', 'enjoy', 'in', 'in', 'in'],
#  'illiterate': ['more', 'than'],
#  'schoolboys': ['many', 'of'],
#  'fifteen.': ['it', 'of'],
#  'true': ['a', 'a', 'a', 'are', 'friend.'],
#  'thought': ['(foolish', 'again', 'all', 'also', 'and'],
#  'extended': ['and', 'more'],
#  'magnificent,': ['and', 'and', 'and', 'but', 'which'],
#  '(as': ['the', 'want'],
#  'painters': ['call', 'the'],
#  'call': ['forth', 'frankenstein', 'her', 'i', 'i'],
#  'it)': ['_keeping;_', 'call'],
#  '_keeping;_': ['and', 'it)'],
#  'greatly': ['altered', 'appeared', 'astonished', 'astonished', 'contributed'],
#  'need': ['a', 'are', 'greatly', 'i', 'i'],
#  'sense': ['a', 'a', 'a', 'and', 'and'],
#  'enough': ['affection', 'far', 'for', 'for', 'force'],
#  'despise': ['himself', 'me', 'to', 'to'],
#  'affection': ['an', 'an', 'and', 'and', 'and'],
#  'mind.': ['benevolent', 'but', 'dejected', 'eager', 'her'],
#  'well,': ['and', 'and', 'and', 'and', 'be'],
#  'useless': ['a', 'and', 'are', 'authors', 'complaints;'],
#  'complaints;': ['i', 'useless'],
#  'find': ['a', 'a', 'a', 'a', 'cannot'],
#  'wide': ['a', 'and', 'atlantic', 'extents', 'field'],
#  'ocean,': ['amidst', 'and', 'frozen', 'nor', 'the'],
#  'nor': ['any', 'any', 'by', 'can', 'can'],
#  'merchants': ['among', 'and'],
#  'seamen.': ['and', 'yet'],
#  'feelings,': ['and', 'and', 'and', 'but', 'even'],
#  'unallied': ['feelings,', 'to'],
#  'dross': ['of', 'the'],
#  'human': ['a', 'a', 'a', 'a', 'a'],
#  'nature,': ['and', 'and', 'beat', 'but', 'but'],
#  'beat': ['even', 'heart', 'nature,', 'pulse', 'pulse'],
#  'rugged': ['and', 'bosoms.', 'hills,', 'mountains', 'roads.'],
#  'bosoms.': ['my', 'rugged'],
#  'lieutenant,': ['for', 'my'],
#  'instance,': ['for', 'is'],
#  'wonderful': ['and', 'and', 'and', 'and', 'and'],
#  'enterprise;': ['and', 'he'],
#  'madly': ['desirous', 'is'],
#  'desirous': ['is', 'madly', 'of', 'to', 'to'],
#  'glory,': ['of', 'or'],
#  'rather,': ['or', 'or', 'stay,', 'to'],
#  'word': ['_honour_,', 'a', 'any', 'chance', 'every'],
#  'phrase': ['"project', '"project', '"project', '"project', 'more'],
#  'characteristically,': ['more', 'of'],
#  'advancement': ['in', 'of'],
#  'profession.': ['he', 'his'],
#  'englishman,': ['an', 'and', 'john', 'young'],
#  'midst': ['of', 'of', 'of', 'the', 'the'],
#  'national': ['and', 'of'],
#  'professional': ['and', 'prejudices,'],
#  'prejudices,': ['professional', 'unsoftened'],
#  'unsoftened': ['by', 'prejudices,'],
#  'cultivation,': ['by', 'retains'],
#  'retains': ['cultivation,', 'some'],
#  'noblest': ['endowments', 'the'],
#  'endowments': ['noblest', 'of'],
#  'humanity.': ['i', 'of'],
#  'him': ['a', 'a', 'address', 'addressed', 'afforded'],
#  'board': ['a', 'a', 'on', 'on', 'on'],
#  'whale': ['a', 'vessel;'],
#  'vessel;': ['finding', 'whale'],
#  'finding': ['a', 'and', 'and', 'curiosity.', 'however,'],
#  'unemployed': ['in', 'was'],
#  'city,': ['i', 'lake', 'our', 'this', 'this'],
#  'assist': ['him,', 'in', 'me', 'me;', 'my'],
#  'master': ['become', 'complete', 'is', 'of', 'of'],
#  'person': ['a', 'a', 'a', 'a', 'from'],
#  'disposition': ['and', 'and', 'and', 'benevolent', 'excellent'],
#  'remarkable': ['been', 'for', 'in', 'is'],
#  'gentleness': ['and', 'and', 'and', 'and', 'and'],
#  'mildness': ['of', 'of', 'the', 'the', 'to'],
#  'discipline.': ['his', 'this'],
#  'circumstance,': ['added', 'single', 'that', 'this'],
#  'added': ['and', 'blindness,', 'circumstance,', 'have', 'life,'],
#  'well-known': ['a', 'a', 'and', 'form', 'his'],
#  'integrity': ['and', 'and', 'his', 'of', 'the'],
#  'courage,': ['dauntless', 'made', 'new', 'therefore,', 'you'],
#  'very': ['a', 'a', 'a', 'a', 'a'],
#  'him.': ['a', 'astonished', 'at', 'beaufort', 'but'],
#  'youth': ['_felix,', 'a', 'a', 'and', 'and'],
#  'solitude,': ['in', 'my'],
#  'best': ['and', 'assistants', 'hope', 'houses', 'it'],
#  'spent': ['a', 'agatha', 'and', 'being', 'but'],
#  'feminine': ['and', 'attentions', 'fosterage,', 'last'],
#  'fosterage,': ['feminine', 'has'],
#  'refined': ['and', 'and', 'by', 'more', 'so'],
#  'groundwork': ['of', 'the'],
#  'overcome': ['an', 'and', 'by', 'by', 'by'],
#  'intense': ['alarm,', 'an', 'application', 'awoke', 'distaste'],
#  'distaste': ['intense', 'to'],
#  'usual': ['brutality', 'hour', 'my', 'occupations', 'quantity'],
#  'brutality': ['exercised', 'of', 'usual', 'was'],
#  'exercised': ['and', 'brutality', 'my', 'on'],
#  'ship:': ['board', 'i'],
#  'believed': ['ago,', 'everybody', 'first', 'have', 'i'],
#  'necessary,': ['absolutely', 'and', 'and', 'and', 'be'],
#  'heard': ['a', 'a', 'amid', 'and', 'and'],
#  'mariner': ['a', 'equally'],
#  'equally': ['are', 'be', 'docile;', 'horrible.', 'mariner'],
#  'noted': ['equally', 'for'],
#  'kindliness': ['his', 'of'],
#  'respect': ['and', 'and', 'i', 'man', 'the'],
#  'obedience': ['and', 'paid'],
#  'paid': ['a', 'a', 'and', 'be', 'by'],
#  'crew,': ['his', 'i'],
#  'peculiarly': ['attracted', 'fortunate', 'fortunate', 'had', 'happy'],
#  'fortunate': ['chance', 'country,', 'how', 'in', 'more'],
#  'being': ['a', 'a', 'a', 'a', 'a'],
#  'secure': ['a', 'a', 'and', 'foundations,', 'him'],
#  'rather': ['a', 'a', 'a', 'account', 'alarmed'],
#  'romantic': ['a', 'castle', 'its', 'manner,'],
#  'manner,': ['and', 'and', 'cordial', 'during', 'from'],
#  'lady': ['a', 'a', 'died,', 'of', 'on'],
#  'owes': ['to', 'who'],
#  'happiness': ['a', 'among', 'and', 'and', 'and'],
#  'her': ['a', 'a', 'accused', 'acquittal.”', 'across'],
#  'this,': ['and', 'and', 'and', 'briefly,', 'but'],
#  'briefly,': ['is', 'this,'],
#  'story.': ['his', 'i', 'my', 'some', 'some'],
#  'ago': ['he', 'moment', 'years', 'you'],
#  'loved': ['a', 'ago,', 'and', 'and', 'and'],
#  'young': ['a', 'a', 'a', 'a', 'a'],
#  'russian': ['lady', 'young'],
#  'moderate': ['a', 'capacity', 'fortune,', 'fortune,', 'of'],
#  'fortune,': ['and', 'competent', 'could', 'moderate', 'moderate'],
#  'having': ['a', 'absence.”', 'after', 'after', 'after'],
#  'amassed': ['a', 'having'],
#  'considerable': ['a', 'a', 'a', 'a', 'a'],
#  'sum': ['a', 'a', 'considerable', 'in', 'not'],
#  'prize-money,': ['in', 'the'],
#  'father': ['a', 'again', 'again;', 'aged', 'and'],
#  'girl': ['a', 'and', 'came', 'confirmed', 'consented'],
#  'consented': ['and', 'girl', 'have', 'have', 'i'],
#  'match.': ['he', 'the'],
#  'saw': ['a', 'a', 'a', 'a', 'a'],
#  'mistress': ['former', 'his', 'his', 'once', 'was'],
#  'once': ['and', 'and', 'and', 'at', 'at'],
#  'destined': ['ceremony;', 'for', 'myself', 'the', 'to'],
#  'ceremony;': ['but', 'destined'],
#  'she': ['abode.', 'accused', 'addressed', 'adorned:', 'adversity.'],
#  'bathed': ['in', 'was'],
#  'tears,': ['and', 'but', 'her', 'her,', 'in'],
#  'throwing': ['and', 'and', 'herself', 'myself'],
#  'herself': ['accused', 'accuses', 'at', 'at', 'away.'],
#  'feet,': ['entreated', 'his'],
#  'spare': ['her,', 'me;', 'to', 'to'],
#  'her,': ['after', 'against', 'against', 'and', 'and'],
#  'confessing': ['at', 'her,'],
#  'same': ['accidents', 'account', 'advantages,', 'as', 'assertion;'],
#  'another,': ['but', 'loved'],
#  'poor,': ['a', 'and', 'good', 'helpless,', 'justine,'],
#  'consent': ['a', 'father’s', 'from', 'never', 'not'],
#  'union.': ['my', 'our', 'the', 'this', 'yet'],
#  'generous': ['and', 'and', 'frankenstein!', 'friend', 'her'],
#  'reassured': ['friend', 'the'],
#  'suppliant,': ['and', 'the'],
#  'informed': ['apparition,', 'be', 'being', 'instantly', 'me'],
#  'name': ['associated', 'gutenberg-tm', 'her', 'i', 'latter'],
#  'lover,': ['but', 'her', 'her', 'instantly'],
#  'instantly': ['abandoned', 'and', 'assumed', 'be', 'carried'],
#  'abandoned': ['had', 'his', 'instantly', 'me,'],
#  'pursuit.': ['he', 'his', 'it', 'it', 'one'],
#  'bought': ['a', 'already', 'dearly', 'experience,', 'repaired,'],
#  'farm': ['a', 'with'],
#  'money,': ['his', 'no', 'no', 'of', 'of'],
#  'designed': ['had', 'to'],
#  'remainder': ['of', 'of', 'of', 'of', 'of'],
#  'life;': ['and', 'and', 'but', 'but', 'his'],
#  'bestowed': ['are', 'creature', 'existence', 'felix', 'had'],
#  'rival,': ['his', 'together'],
#  'together': ['money,', 'rival,', 'whispered', 'with', 'with'],
#  'remains': ['and', 'for', 'for', 'happiness', 'its'],
#  'prize-money': ['his', 'to'],
#  'purchase': ['stock,', 'to'],
#  'stock,': ['and', 'purchase'],
#  'then': ['a', 'added', 'again', 'and', 'and'],
#  'himself': ['a', 'and', 'at', 'bound', 'by'],
#  'solicited': ['himself', 'the', 'their', 'who'],
#  'woman’s': ['a', 'father', 'sedulous', 'young'],
#  'marriage': ['approaching', 'drew', 'early', 'her', 'his'],
#  'lover.': ['but', 'her'],
#  'old': ['an', 'an', 'an', 'an', 'an'],
#  'decidedly': ['man', 'refused,'],
#  'refused,': ['and', 'decidedly', 'i', 'thinking'],
#  'thinking': ['a', 'and', 'himself', 'refused,'],
#  'bound': ['art', 'as', 'be', 'be', 'but'],
#  'honour': ['and', 'and', 'and', 'and', 'and'],
#  'who,': ['a', 'before', 'beings', 'born', 'but'],
#  'found': ['a', 'a', 'a', 'a', 'a'],
#  'inexorable,': ['father', 'quitted'],
#  'quitted': ['again', 'and', 'and', 'geneva', 'geneva.'],
#  'country,': ['america', 'and', 'and', 'but', 'distant'],
#  'returned': ['a', 'again,', 'and', 'and', 'and'],
#  ...}

# %%
with open('frankenstein.txt', encoding='utf-8') as file:
    words = file.read().split()
    
neigh = {}
for i, word in enumerate(words):
    if word not in neigh.keys():
        neigh[word] = []
    if i - 1 > 0:
        neigh[word].append(words[i - 1])
    if i + 1 < len(words):
        neigh[word].append(words[i + 1])

# %% [markdown]
# ### Задача посложнее
#
# У вас есть файл с разметкой «Горя от ума» Грибоедова: https://shorturl.at/quDLT
#
# Значения в нём разделены запятыми и идут в таком порядке:
#
# * `play` — название пьесы
# * `line` — текст строки
# * `line lemmas` — лемматизированный текст строки
# * `line type` — речь персонажа (spoken) или авторская ремарка (stage)
# * `RuSentiLex`, `EmoLex`, `LinisCrowd`, `ChenSkiena`, `ProductSentiRus`, `SentiRusColl`, `Eduard` — оценка эмоциональности строки по мнению того или иного словаря эмоциональной лексики
#
# Считайте его (при помощи `DictReader`-а). Соберите список лемматизированных строк, у которых не менее четырёх словарей сошлись в оценке (имеют одинаковую оценку), а затем составьте частотный словарь из этих строк.

# %%
import csv

# %%
gore_lines = csv.DictReader(open("gore_out_uma_by_line.csv"))

# your code here

# %%
from csv import DictReader
 
lines = DictReader(open('gore_out_uma_by_line.csv', encoding='utf-8'))
correctlines = []
for line in lines:
    ratings = {}
    for rating in [line[src] for src in ['RuSentiLex', 'EmoLex', 'LinisCrowd', 'ChenSkiena', 'ProductSentiRus', 'SentiRusColl', 'Eduard']]:
        if rating not in ratings.keys():
            ratings[rating] = 1
        else:
            ratings[rating] += 1
 
    if max(ratings.values()) >= 4:
        correctlines.append(line['line lemmas'])

freqlist = {}
for line in correctlines:
    for word in line.split():
        if word not in freqlist:
            freqlist[word] = 1
        else:
            freqlist[word] += 1
#freqlist.get(word,0)+1
freqlist
# Out:
# {'светать': 1,
#  'ах': 48,
#  'как': 109,
#  'скоро': 16,
#  'ночь': 15,
#  'минуть': 1,
#  'вчера': 4,
#  'проситься': 1,
#  'спать': 7,
#  'отказ': 1,
#  'ждать': 11,
#  'друг': 24,
#  'нужный': 3,
#  'глаз': 14,
#  'да': 66,
#  'не': 312,
#  'покудова': 1,
#  'скатиться': 1,
#  'со': 16,
#  'стул': 3,
#  'теперь': 27,
#  'вот': 71,
#  'только': 20,
#  'что': 184,
#  'вздремнуть': 1,
#  'уж': 32,
#  'день': 21,
#  'сказать': 48,
#  'они': 52,
#  'господин': 3,
#  'эй': 4,
#  'софья': 19,
#  'павловна': 10,
#  'беда': 11,
#  'зайти': 5,
#  'беседа': 1,
#  'ваш': 35,
#  'за': 54,
#  'вы': 212,
#  'глухой': 3,
#  'алексей': 4,
#  'степаныч': 3,
#  'сударыня': 8,
#  'и': 367,
#  'страх': 10,
#  'их': 9,
#  'брать': 5,
#  'ну': 32,
#  'гость': 4,
#  'неприглашенный': 1,
#  'быть': 122,
#  'мочь': 33,
#  'батюшка': 22,
#  'входить': 4,
#  'просить': 16,
#  'служить': 11,
#  'у': 46,
#  'барышня': 9,
#  'влюблять': 2,
#  'расходиться': 2,
#  'утро': 4,
#  'с': 157,
#  'который': 20,
#  'час': 19,
#  'все': 85,
#  'в': 286,
#  'дом': 13,
#  'подниматься': 3,
#  'седьмой': 1,
#  'осьмой': 1,
#  'девятый': 2,
#  'неправда': 1,
#  'амур': 3,
#  'проклятый': 2,
#  'бы': 46,
#  'ставня': 1,
#  'отнимать': 1,
#  'перевести': 4,
#  'часы': 3,
#  'хоть': 31,
#  'знать': 36,
#  'гонка': 1,
#  'заставлять': 2,
#  'играть': 5,
#  'барин': 2,
#  'ведь': 12,
#  'экий': 1,
#  'шалунья': 1,
#  'ты': 80,
#  'девчонка': 1,
#  'придумывать': 1,
#  'я': 355,
#  'это': 26,
#  'то': 44,
#  'флейта': 2,
#  'слышаться': 2,
#  'будто': 17,
#  'фортопьяно': 1,
#  'для': 26,
#  'слишком': 2,
#  'б': 14,
#  'рано': 6,
#  'нет': 74,
#  'сударь': 16,
#  'лишь': 7,
#  'невзначай': 4,
#  'то-то': 4,
#  'примечать': 1,
#  'ох': 7,
#  'зелье': 1,
#  'баловница': 1,
#  'баловник': 1,
#  'к': 80,
#  'лицо': 17,
#  'ль': 9,
#  'этот': 34,
#  'скромный': 4,
#  'а': 138,
#  'ничто': 10,
#  'кроме': 1,
#  'проказа': 3,
#  'ветер': 4,
#  'на': 119,
#  'ум': 29,
#  'пускать': 3,
#  'ветренник': 1,
#  'сам': 28,
#  'опоминаться': 2,
#  'старик': 5,
#  'почти': 1,
#  'кто': 96,
#  'прийти': 2,
#  'куда': 19,
#  'мы': 94,
#  'сюда': 14,
#  'приходить': 5,
#  'сейчас': 14,
#  'започивать': 1,
#  'целый': 12,
#  'читать': 10,
#  'вишь': 4,
#  'прихоть': 1,
#  'какой': 25,
#  'заводиться': 1,
#  'весь': 64,
#  'по-французски': 2,
#  'вслух': 3,
#  'запираться': 2,
#  'ка': 15,
#  'она': 45,
#  'портить': 1,
#  'годиться': 1,
#  'чтение': 1,
#  'прок': 2,
#  'тот': 48,
#  'большой': 3,
#  'сон': 11,
#  'от': 58,
#  'французский': 3,
#  'книга': 8,
#  'русский': 3,
#  'больно': 4,
#  'спаться': 1,
#  'вставать': 3,
#  'докладываться': 1,
#  'изволить': 11,
#  'же': 47,
#  'идти': 11,
#  'разбудить': 1,
#  'бояться': 9,
#  'будить': 1,
#  'заводить': 2,
#  'квартал': 1,
#  'симфония': 1,
#  'греметь': 2,
#  'полноте': 1,
#  'помиловать': 8,
#  'кричать': 4,
#  'чтобы': 7,
#  'выходить': 4,
#  'из': 32,
#  'пора': 15,
#  'ребенок': 5,
#  'чуть': 10,
#  'дверь': 13,
#  'скрипнуть': 2,
#  'шепнуть': 2,
#  'слышать': 11,
#  'лгать': 2,
#  'лиза': 4,
#  'уходить': 1,
#  'подаль': 1,
#  'себя': 32,
#  'всякий': 10,
#  'готовить': 3,
#  'миновать': 2,
#  'пуще': 4,
#  'печаль': 4,
#  'барский': 2,
#  'гнев': 3,
#  'любовь': 8,
#  'нападывать': 3,
#  'шуметь': 5,
#  'конечно': 10,
#  'расставаться': 3,
#  'тяжело': 1,
#  'до': 19,
#  'свет': 17,
#  'кажется': 4,
#  'мало': 7,
#  'самый': 2,
#  'дело': 17,
#  'рассветать': 1,
#  'обмирать': 1,
#  'вертеться': 1,
#  'перед': 5,
#  'он': 167,
#  'помнить': 9,
#  'врать': 3,
#  'становиться': 16,
#  'поклон': 4,
#  'отвешивать': 1,
#  'пойти': 14,
#  'сердце': 7,
#  'место': 3,
#  'смотреть': 8,
#  'взглядывать': 4,
#  'окно': 2,
#  'валить': 1,
#  'народ': 5,
#  'по': 48,
#  'улица': 1,
#  'давно': 13,
#  'стук': 2,
#  'ходьба': 1,
#  'мести': 1,
#  'убирать': 1,
#  'счастливый': 6,
#  'наблюдать': 2,
#  'власть': 3,
#  'ответ': 7,
#  'попадать': 4,
#  'еще': 16,
#  'потерпеть': 1,
#  'скука': 4,
#  'бог': 18,
#  'прочь': 3,
#  'взять': 10,
#  'рука': 13,
#  'оказия': 1,
#  'молчалин': 23,
#  'брат': 15,
#  'зачем': 13,
#  'здесь': 27,
#  'здравствовать': 2,
#  'так': 63,
#  'забота': 2,
#  'вместе': 3,
#  'сводить': 6,
#  'прогулка': 2,
#  'нельзя': 11,
#  'ли': 59,
#  'постель': 1,
#  'прыг': 1,
#  'небылица': 1,
#  'плод': 1,
#  'кузнецкий': 2,
#  'мост': 2,
#  'вечный': 2,
#  'француз': 2,
#  'оттуда': 2,
#  'мода': 3,
#  'автор': 1,
#  'муза': 1,
#  'губитель': 1,
#  'карман': 1,
#  'когда': 28,
#  'избавлять': 2,
#  'творец': 2,
#  'шляпка': 1,
#  'чепец': 1,
#  'шпилька': 1,
#  'булавка': 1,
#  'книжный': 1,
#  'бисквитный': 1,
#  'лавка': 1,
#  'позволять': 5,
#  'кружиться': 1,
#  'голова': 14,
#  'испуг': 2,
#  'дух': 3,
#  'переводить': 2,
#  'едва': 4,
#  'вбегать': 3,
#  'проворно': 2,
#  'смешаться': 1,
#  'благодарить': 3,
#  'покорно': 2,
#  'помешать': 1,
#  'испужать': 1,
#  'расстраивать': 1,
#  'должность': 2,
#  'служба': 9,
#  'хлопотня': 1,
#  'приставать': 2,
#  'другой': 31,
#  'но': 38,
#  'новый': 11,
#  'хлопоты': 2,
#  'чтоб': 28,
#  'обманывать': 1,
#  'попрекать': 1,
#  'без': 22,
#  'толк': 4,
#  'всегда': 7,
#  'журить': 2,
#  'плакать': 4,
#  'говорить': 19,
#  'об': 30,
#  'твой': 7,
#  'радеть': 1,
#  'воспитание': 2,
#  'колыбель': 1,
#  'мать': 5,
#  'умирать': 2,
#  'уметь': 7,
#  'принанимать': 1,
#  'мадам': 3,
#  'розье': 1,
#  'второй': 1,
#  'старушка': 2,
#  'золото': 3,
#  'надзор': 1,
#  'приставлять': 1,
#  'умный': 10,
#  'нрав': 7,
#  'тихий': 2,
#  'редкий': 3,
#  'правило': 2,
#  'лишний': 3,
#  'год': 22,
#  'пятьсот': 1,
#  'рубль': 1,
#  'сманивать': 1,
#  'допускать': 1,
#  'сила': 5,
#  'надобно': 5,
#  'иной': 13,
#  'образец': 3,
#  'пример': 5,
#  'отец': 12,
#  'хвастать': 1,
#  'сложение': 1,
#  'однако': 15,
#  'бодрый': 2,
#  'свежий': 3,
#  'доживать': 2,
#  'седина': 2,
#  'осмеливаться': 2,
#  'молчать': 5,
#  'ужасный': 3,
#  'век': 15,
#  'начинать': 4,
#  'умудряться': 1,
#  'лет': 2,
#  'даваться': 6,
#  'язык': 7,
#  'побродяга': 1,
#  'билет': 3,
#  'танец': 2,
#  'пение': 1,
#  'нежность': 2,
#  'вздох': 1,
#  'жена': 5,
#  'скоморох': 1,
#  'посетитель': 1,
#  'безродный': 1,
#  'пригревать': 1,
#  'вводить': 3,
#  'мой': 61,
#  'семейство': 2,
#  'давать': 28,
#  'чин': 14,
#  'асессор': 1,
#  'секретарь': 2,
#  'москва': 21,
#  'через': 5,
#  'содейство': 1,
#  'коптеть': 1,
#  'тверь': 1,
#  'никак': 1,
#  'растолковывать': 2,
#  'комната': 9,
#  'или': 12,
#  'хотеть': 22,
#  'случай': 4,
#  'давич': 6,
#  'перепугать': 1,
#  'голос': 10,
#  'чрезвычайно': 1,
#  'бросаться': 1,
#  'нога': 9,
#  'пожалуй': 2,
#  'суматоха': 1,
#  'слагать': 1,
#  'наделать': 2,
#  'тревога': 3,
#  'смутный': 1,
#  'безделица': 1,
#  'тревожить': 1,
#  'понимать': 3,
#  'тогда': 5,
#  'история': 2,
#  'рассказывать': 8,
#  'видеть': 12,
#  'сначала': 1,
#  'трава': 2,
#  'какой-то': 11,
#  'вспомнить': 2,
#  'наяву': 2,
#  'вдруг': 7,
#  'милый': 12,
#  'человек': 43,
#  'один': 23,
#  'увидеть': 4,
#  'знакомый': 7,
#  'являться': 9,
#  'тут': 21,
#  'вкрадчивый': 1,
#  'робкий': 2,
#  'бедность': 1,
#  'рожать': 2,
#  'бедный': 3,
#  'пара': 2,
#  'потом': 9,
#  'пропадать': 1,
#  'луг': 1,
#  'небо': 1,
#  'темный': 2,
#  'довершение': 1,
#  'чудо': 3,
#  'раскрываться': 1,
#  'пол': 2,
#  'бледный': 1,
#  'смерть': 3,
#  'дыбом': 1,
#  'волос': 4,
#  'гром': 1,
#  'распахиваться': 2,
#  'зверь': 1,
#  'врознь': 3,
#  'мучить': 1,
#  'сидеть': 6,
#  'тащить': 1,
#  'провожать': 1,
#  'стон': 2,
#  'рев': 1,
#  'хохот': 3,
#  'свист': 1,
#  'чудовище': 1,
#  'вслед': 1,
#  'просыпаться': 2,
#  'кто-то': 4,
#  'думать': 9,
#  'бежать': 4,
#  'оба': 1,
#  'находить': 12,
#  'коли': 4,
#  'обман': 2,
#  'черт': 3,
#  'цветок': 1,
#  'забавно': 2,
#  'исправный': 1,
#  'сзывать': 1,
#  'заря': 3,
#  'спешить': 4,
#  'бумага': 2,
#  'припадать': 1,
#  'усердие': 2,
#  'письменный': 1,
#  'бывать': 4,
#  'странный': 4,
#  'странно': 2,
#  'искать': 4,
#  'повыкинуть': 1,
#  'вздор': 6,
#  'где': 23,
#  'там': 18,
#  'склад': 1,
#  'поди': 7,
#  'ложиться': 2,
#  'уснуть': 1,
#  'опять': 5,
#  'разбирать': 2,
#  'нести': 1,
#  'доклад': 2,
#  'ход': 2,
#  'справка': 2,
#  'противуречье': 1,
#  'многое': 1,
#  'дельно': 1,
#  'смертельно': 1,
#  'множество': 2,
#  'накопляться': 1,
#  'воля': 1,
#  'оно': 3,
#  'засаживаться': 2,
#  'обычай': 1,
#  'такой': 15,
#  'подписывать': 1,
#  'плечо': 1,
#  'долой': 2,
#  'праздник': 2,
#  'потеха': 1,
#  'смех': 10,
#  'темно': 1,
#  'замирать': 1,
#  'душа': 16,
#  'грех': 2,
#  'молва': 2,
#  'хороший': 5,
#  'судить': 4,
#  'задумываться': 1,
#  'принуждать': 2,
#  'таков': 5,
#  'посудить': 1,
#  'двор': 6,
#  'ж': 20,
#  'печальный': 1,
#  'нейти': 2,
#  'забываться': 2,
#  'музыка': 2,
#  'время': 11,
#  'плавно': 1,
#  'судьба': 5,
#  'беречь': 2,
#  'ни': 31,
#  'беспокойство': 2,
#  'сомнение': 5,
#  'горе': 5,
#  'из-за': 1,
#  'угол': 2,
#  'глупый': 4,
#  'суждение': 5,
#  'жаловать': 4,
#  'никогда': 4,
#  'ан': 1,
#  'пророк': 1,
#  'во': 15,
#  'веко': 1,
#  'московский': 5,
#  'при': 18,
#  'звезда': 1,
#  'богатый': 5,
#  'между': 6,
#  'разуметься': 1,
#  'деньги': 1,
#  'пожить': 2,
#  'бал': 12,
#  'например': 7,
#  'полковник': 3,
#  'скалозуб': 13,
#  'золотой': 1,
#  'мешок': 1,
#  'метить': 3,
#  'генерал': 4,
#  'весело': 4,
#  'выслушивать': 1,
#  'о': 24,
#  'фрунт': 2,
#  'ряд': 1,
#  'равный': 4,
#  'вода': 5,
#  'речистый': 1,
#  'хитрый': 1,
#  'военный': 3,
#  'статский': 2,
#  'чувствительный': 1,
#  'веселый': 5,
#  'острый': 1,
#  'александр': 6,
#  'андреич': 6,
#  'чацкий': 22,
#  'смущать': 2,
#  'проходить': 3,
#  'воротить': 1,
#  'помниться': 2,
#  'славно': 3,
#  'пересмеивать': 1,
#  'болтать': 1,
#  'шутить': 7,
#  'слеза': 2,
#  'обливаться': 1,
#  'жить': 8,
#  'смеяться': 3,
#  'недаром': 4,
#  'известно': 2,
#  'воротиться': 6,
#  'сколько': 3,
#  'утрачивать': 1,
#  'бедняжка': 1,
#  'три': 17,
#  'послушать': 8,
#  'вольность': 2,
#  'очень': 11,
#  'ветрено': 1,
#  'поступать': 1,
#  'укорять': 2,
#  'неверность': 1,
#  'правда': 7,
#  'воспитывать': 1,
#  'расти': 1,
#  'привычка': 1,
#  'каждый': 3,
#  'неразлучный': 1,
#  'съезжать': 1,
#  'казаться': 5,
#  'скучно': 1,
#  'редко': 1,
#  'посещать': 1,
#  'наш': 16,
#  'прикидываться': 1,
#  'влюбленный': 2,
#  'взыскательный': 1,
#  'огорчать': 1,
#  'особенно': 3,
#  'задумывать': 2,
#  'высоко': 1,
#  'охота': 5,
#  'странствовать': 1,
#  'носиться': 2,
#  'край': 3,
#  'лечиться': 1,
#  'кислый': 1,
#  'болезнь': 1,
#  'чай': 8,
#  'вольно': 3,
#  'верно': 2,
#  'смешно': 4,
#  'любить': 5,
#  'враг': 2,
#  'дерзость': 2,
#  'застенчиво': 1,
#  'несмело': 2,
#  'можно': 7,
#  'провесть': 1,
#  'побелеть': 1,
#  'занятый': 2,
#  'весть': 3,
#  'жать': 1,
#  'тетушка': 3,
#  'голубушка': 1,
#  'схоронить': 1,
#  'свой': 15,
#  'досада': 3,
#  'суметь': 2,
#  'забывать': 7,
#  'чернить': 1,
#  'поседеть': 1,
#  'обо': 4,
#  'заговорить': 1,
#  'прощать': 13,
#  'право': 1,
#  'святой': 2,
#  'дурацкий': 1,
#  'рад': 15,
#  'посмотреть': 5,
#  'удивлять': 1,
#  'прием': 1,
#  'неделя': 2,
#  'вдвоем': 2,
#  'надоедать': 3,
#  'вспоминаться': 1,
#  'сорок': 3,
#  'пять': 6,
#  'миг': 2,
#  'прищурить': 1,
#  'верста': 1,
#  'много': 6,
#  'седьмисот': 1,
#  'пронестись': 1,
#  'буря': 1,
#  'растериваться': 1,
#  'падать': 2,
#  'раз': 13,
#  'подвиг': 1,
#  'награда': 1,
#  'напоследок': 1,
#  'лошадь': 3,
#  'знобить': 1,
#  'тешить': 1,
#  'если': 12,
#  'ей-богу': 1,
#  'минута': 4,
#  'поминать': 3,
#  'промелькнуть': 1,
#  'отворять': 1,
#  'вопрос': 3,
#  'моряк': 1,
#  'повстречать': 1,
#  'почтовый': 1,
#  'карета': 10,
#  'полагать': 2,
#  'блаженный': 1,
#  'веровать': 1,
#  'тепло': 2,
#  'боже': 10,
#  'ужли': 4,
#  'вечер': 5,
#  'длинный': 1,
#  'исчезать': 2,
#  'стол': 2,
#  'уголок': 2,
#  'вздрагивать': 2,
#  'столик': 1,
#  'ребячество': 2,
#  'седьмнадцать': 1,
#  'расцветать': 1,
#  'прелестно': 1,
#  'неподражаемый': 1,
#  'дума': 2,
#  'полнота': 1,
#  'смущаться': 1,
#  'быстрый': 1,
#  'любопытный': 1,
#  'взгляд': 3,
#  'удивляться': 2,
#  'показывать': 1,
#  'завтра': 2,
#  'два': 16,
#  'свататься': 1,
#  'успевать': 2,
#  'промах': 1,
#  'стих': 1,
#  'альбом': 1,
#  'хорошо': 3,
#  'английский': 4,
#  'клоб': 2,
#  'дядюшка': 2,
#  'отпрыгивать': 1,
#  'турок': 1,
#  'грек': 1,
#  'черномазенький': 1,
#  'ножка': 1,
#  'журавлиный': 1,
#  'столовая': 1,
#  'гостиная': 1,
#  'трое': 1,
#  'бульварный': 1,
#  'полвека': 1,
#  'молодиться': 1,
#  'родные': 1,
#  'мильон': 1,
#  'помощь': 2,
#  'сестрица': 2,
#  'европа': 1,
#  'породниться': 1,
#  'солнышко': 1,
#  'клад': 1,
#  'зелень': 1,
#  'раскрашивать': 1,
#  'вид': 4,
#  'роща': 1,
#  'толстый': 1,
#  'его': 15,
#  'артист': 1,
#  'тощий': 1,
#  'открывать': 6,
#  'ширма': 1,
#  'секретно': 2,
#  'спрятать': 1,
#  'щелкать': 1,
#  'соловей': 1,
#  'певец': 1,
#  'зима': 1,
#  'погода': 1,
#  'летний': 1,
#  'ученый': 1,
#  'комитет': 1,
#  'поселяться': 1,
#  'грамота': 1,
#  'никто': 9,
#  'учиться': 2,
#  'суждено': 1,
#  'сыщещь': 1,
#  'пятно': 1,
#  'пространствовать': 1,
#  'домой': 4,
#  'дым': 2,
#  'отечество': 3,
#  'сладкий': 1,
#  'приятный': 1,
#  'свесть': 1,
#  'перечитывать': 1,
#  'девушка': 1,
#  'минерва': 1,
#  'фрейлина': 1,
#  'екатерина': 2,
#  'первый': 7,
#  'воспитанница': 1,
#  'моська': 2,
#  'полный': 2,
#  'переходить': 1,
#  'нынче': 12,
#  'издревле': 1,
#  'хлопотать': 2,
#  'набирать': 1,
#  'учитель': 2,
#  'полка': 3,
#  'наука': 2,
#  'далекий': 1,
#  'признавать': 2,
#  'велеть': 5,
#  'историк': 1,
#  'географ': 1,
#  'ментор': 1,
#  'колпак': 1,
#  'халат': 1,
#  'перст': 1,
#  'указательный': 1,
#  'признак': 1,
#  'учение': 2,
#  'тревожный': 1,
#  'немец': 3,
#  'спасение': 1,
#  'гильом': 2,
#  'подбивать': 1,
#  'ветерок': 1,
#  'женатый': 5,
#  'какой-нибудь': 1,
#  'княгиня': 7,
#  'пульхерия': 2,
#  'андревна': 2,
#  'танцмейстер': 1,
#  'кавалер': 1,
#  'потребовать': 2,
#  'имение': 3,
#  'тон': 1,
#  'каков': 2,
#  'господствовать': 1,
#  'смешение': 1,
#  'нижегородский': 1,
#  'смесь': 1,
#  'мудрено': 1,
#  'скроить': 1,
#  'новость': 1,
#  'пользоваться': 1,
#  'свидание': 3,
#  'оживлять': 1,
#  'говорливый': 1,
#  'разве': 2,
#  'глупо': 1,
#  'кстати': 3,
#  'сламывать': 2,
#  'безмолвие': 2,
#  'печать': 1,
#  'пожаловать': 4,
#  'списывать': 1,
#  'змея': 1,
#  'спрашивать': 7,
#  'случаться': 4,
#  'ошибка': 1,
#  'добро': 2,
#  'кто-нибудь': 5,
#  'детство': 2,
#  'мягко': 1,
#  'нежно': 1,
#  'незрелый': 1,
#  'звонок': 1,
#  'снеговой': 1,
#  'пустыня': 1,
#  'сломя': 1,
#  'строгий': 2,
#  'полчаса': 1,
#  'холодность': 2,
#  'терпеть': 2,
#  'слово': 17,
#  'колок': 1,
#  'клониться': 1,
#  'чей-нибудь': 1,
#  'вред': 2,
#  'лад': 3,
#  'посмеяться': 1,
#  'огонь': 2,
#  'обед': 6,
#  'писать': 7,
#  'грянуть': 2,
#  'облако': 1,
#  'здорово': 4,
#  'собрание': 2,
#  'важный': 2,
#  'садиться': 6,
#  'объявлять': 2,
#  'похорошеть': 1,
#  'молодой': 3,
#  'нету': 3,
#  'что-то': 7,
#  'вскользь': 1,
#  'надежда': 4,
#  'занестись': 1,
#  'заколдованный': 1,
#  'избаловывать': 1,
#  'ничуть': 3,
#  'сниться': 1,
#  'отгадчик': 1,
#  'верить': 4,
#  'пустой': 8,
#  'встречать': 4,
#  'подписка': 1,
#  'дама': 2,
#  'несколько': 4,
#  'подобно': 1,
#  'свое': 2,
#  'подробно': 1,
#  'скитаться': 1,
#  'столько': 1,
#  'откудова': 3,
#  'объехать': 2,
#  'сотый': 1,
#  'доля': 1,
#  'спешивать': 1,
#  'заезжать': 1,
#  'подробность': 1,
#  'малый': 4,
#  'всюду': 2,
#  'виноватый': 5,
#  'крюк': 1,
#  'полмить': 1,
#  'нищий': 1,
#  'франт': 1,
#  'приятель': 3,
#  'отъявленный': 2,
#  'мот': 1,
#  'сорванец': 1,
#  'комиссия': 1,
#  'создатель': 2,
#  'петрушка': 1,
#  'вечно': 3,
#  'обновка': 1,
#  'раздирать': 1,
#  'локоть': 1,
#  'доставать': 4,
#  'календарь': 3,
#  'пономарь': 1,
#  'постоять': 4,
#  'лист': 2,
#  'черкнуть': 1,
#  'записной': 1,
#  'против': 2,
#  'будущий': 2,
#  'прасковья': 2,
#  'федоровна': 1,
#  'вторник': 1,
#  'звать': 9,
#  'форель': 1,
#  'пофилософствовать': 1,
#  'вскружиться': 1,
#  'беречься': 1,
#  'есть': 2,
#  'свариваться': 1,
#  'отмечать': 1,
#  'четверг': 4,
#  'погребение': 1,
#  'род': 4,
#  'людской': 1,
#  'забвение': 1,
#  'туда': 5,
#  'должный': 5,
#  'лезть': 3,
#  'ларчик': 1,
#  'память': 3,
#  'намерен': 1,
#  'оставлять': 5,
#  'житие': 2,
#  'похвальный': 2,
#  'покойник': 2,
#  'почтенный': 1,
#  'камергер': 1,
#  'ключ': 2,
#  'сын': 2,
#  'доставлять': 1,
#  'переженить': 1,
#  'внучонок': 1,
#  'скончаться': 1,
#  'прискорбный': 1,
#  'кузьма': 1,
#  'петрович': 5,
#  'мир': 4,
#  'может': 2,
#  'пятница': 1,
#  'суббота': 1,
#  'вдова': 2,
#  'докторша': 1,
#  'крестить': 1,
#  'родить': 2,
#  'расчет': 1,
#  'ко': 4,
#  'глядеть': 9,
#  'отчего': 1,
#  'приезд': 3,
#  ...}

# %%
assessm = [line['RuSentiLex'], line['EmoLex'], line['LinisCrowd'], line['ChenSkiena'], line['ProductSentiRus'], line['SentiRusColl'], line['Eduard']]
if assessm.count('-1') >=4 or assessm.count('0') >=4 or assessm.count('1') >=4

# %% [markdown]
# ### ОС - <a href = 'https://clck.ru/at35Y'>clck.ru/at35Y</a>
